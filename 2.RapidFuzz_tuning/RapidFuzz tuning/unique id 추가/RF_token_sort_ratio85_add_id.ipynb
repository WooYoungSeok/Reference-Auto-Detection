# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Sample data loading step
data = pd.read_csv('2008_2022_한국현대문학_인문_복합학_추가데이터_참고문헌_박완서.xlsx - Sheet1.csv')

nan_count = data['title'].isnull().sum()
print(f"Number of NaN values in the 'title' column: {nan_count}")

# Drop rows where 'title' or 'author' is NaN
data = data.dropna(subset=['title', 'author'])
# Out:
# Number of NaN values in the 'title' column: 7

# %%
data.groupby('author').size().sort_values(ascending=False).head(10)
# Out:
# author
# 박완서    863
# 김윤식    120
# 이선미    110
# 김은하     89
# 김양선     80
# 권명아     72
# 김은정     56
# 최인욱     55
# 김미영     51
# 신수정     51
# dtype: int64

# %%
# Group data by author
for author, group in data.groupby('author'):
    titles = group['title'].unique()

    print(titles)
# Out:
# ['1.20 학병사기, 1권']
# ['5․18 민중항쟁과 정치․역사․사회 2']
# ['Necropolitics']
# ['통과의례']
# ['감각의 박물학']
# ['호모 사케르']
# ['호모 사케르-주권 권력과 벌거벗은 생명' '예외상태']
# ['Le "Cycle du barrage" dans l\'oeuvre de Marguerite Duras']
# ['Willful subject']
# ['말, 살, 흙']
# ['박정희 정권과 농민의 연계성']
# ['The Cultural Politics of Emotion']
# ['Desire and Domestic Fiction: A Political History of the Novel']
# ['Untranslatability: The Case of Pronouns of Address in Literature']
# ['상상의 공동체']
# ['최근 여성학의 쟁점과여성주의윤리학']
# ['Modernity and Self-Identity : Self and Identity in the late Modern Age']
# ['Gender Roles and Wpmen’s Sleep in Mid and Later Life: a Quantitative Approach']
# ['To Save the Children of Korea : The Cold War Origins of International Adoption']
# ["l'autobiographie"]
# ['諷刺(Satire)']
# ['Touching ; The Human Significance of the skin']
# ['기억의 공간']
# ['변신']
# ['에티카']
# ['에티카']
# ['Idiomatisme et traduction']
# ['Le nom propre en traduction anglais ↔ francais, Gap']
# ['Introduction to Semantics and Translation, Horsleys Green, England']
# ['La traduction et la lettre ou l\'auberge du lointain, collection "L\'ordre Philosophique']
# ['불의 정신분석']
# ['In Other Words : A Coursebook on Translation']
# ['장편소설과 민중언어']
# ['서사란 무엇인가']
# ['Versus : repérages et paramètres anglais↔ français 1']
# ['감정의 거시사회학-감정은 사회를 어떻게 움직이는가?' '감정과 사회학']
# ['Marguerite Duras au risque de la philosophie: Pascal, Rousseau, Diderot, Kierkegaard, Lévinas']
# ['반사회적 가족']
# ['Forget Memory']
# ['액체근대']
# ['제2의 성 상·하']
# ['노년 1' '노년 2']
# ['Women’s Way of Knowing']
# ['Class strategies and the Education Market: The middle Classes and Social Advantage']
# ['멜로드라마와 모더니티']
# ['Illuminations: Essays and Reflections, In Hannah Arendt']
# ['발터벤야민의 문예이론']
# ['The Social Construction of Reality']
# ['물질과 기억']
# ['정동이론']
# ['La traduction et la lettre ou l’auberge du lointain']
# ['우울증']
# ['Sleep and society: An epidemiological perspective']
# ['Raymond Williams, Resources of Hope: Culture,Democracy, Socialism']
# ['Christine, Marguerite Duras']
# ['The hidden meaning and its hiding place: The postmodern semantics of Freud']
# ['사회 생태론, In 생태학의 담론']
# ['참을 수없는 몸의 무거움: 페미니즘, 서구문화, 몸']
# ['Impoliteness in Interaction']
# ['Modernism : A Guide To European Literature 1890-1930']
# ['변신 : 되기의 유물론을 향해' '유목적 주체']
# ['이야기해 그리고 다시 살아나']
# ['Discourse Analysis']
# ['우리의 의지에 반하여']
# ['라깡과 정신의학']
# ['브뤼노 라투르의 과학인문학 편지']
# ['Seniors, Volunteers, and Families of an Intergenerational Program in a Rural Community']
# ['의미를 체현하는 육체' '안티고네의 주장' '젠더 트러블' '혐오발언']
# ['비폭력의 힘－윤리학－정치학 잇기' '젠더 트러블' '불확실한 삶 –애도와 폭력의 권력들'
#  'The Psychic Life of Power']
# ['불확실한 삶-애도와 폭력의 권력들']
# ['혐오발언']
# ['융 심리학 입문']
# ['Analysis of ‘The Bear Came Over the Mountain’ by Alice Munro']
# ['화이트칼라']
# ['워렌, 안동림 역, 소설의 분석']
# ['영웅과 어머니 원형']
# ['융 심리학 해설']
# ["Sous le ciel, la paix, Ch'oe Yun et P. Maurus, Arles, Actes Sud"]
# ['모더니티의 다섯 얼굴']
# ['정신분석적 발달 이론']
# ['프로이트 심리학입문']
# ['An Intergenerational Program for Persons With Dementia Using Montessori Methods']
# ['Psychiatric Dictionary']
# ['새로운 과학과 문명의 전환' '생명의 그물']
# ['육식의 성정치']
# ['The Disorder of Women: Democracy, Feminism and Political Theory']
# ['Gender and Conversational Interaction']
# ['Taking time seriously: A theory of socioemotional selectivity']
# ['Marguerite Duras: Les lieux du ravissement']
# ['하드보일드 센티멘털리티']
# ['Practicing New Historicism']
# ['Discourse, consciousness, and time']
# ['자아의 원천들' '불안한 현대사회']
# ['원화와 작화']
# ['Story and Discourse(이야기와 談論)']
# ['Reading Motherʹs Tale‐Reconstructing Womenʹs Space inAmy Tan and Zhang Jie']
# ['Haunting the Korean diaspora : shame, secrecy, and the forgotten war']
# ['Year of impossible goodbyes']
# ['Le signifiant imaginaire']
# ['만들어진 우울증']
# ['Worlds of Sense: Exploring the Senses in History And Across Cultures']
# ['Radical Pragmatics']
# ['Individual behavior']
# ['The Deepest Sense']
# ['The Time of Generations']
# ['페미니즘의 투쟁']
# ["Poétique de l'enfance chez Marguerite Duras"]
# ['24/7 잠의 종말']
# ['Structuralist Poetics: Structuralism, Linguistics and Study of Literature']
# ['Towards an anatomy of impoliteness'
#  'Impoliteness revisited: with special reference to dynamic and prosodic aspects']
# ['망각: 알츠하이머병이란 무엇인가?']
# ['Themes and Motifs in Western Literature']
# ['Dictionary of Philosophy']
# ['Can "Metaphor" Be Translated?']
# ["Russell's sign. Subtle hand changes in patients with bulimia nervosa"]
# ['도시의 정치경제학' '반란의 도시']
# ['Factual Fictions: The Origins of The English Novel']
# ['Writing as a Way of Healing : How Telling Our Stories Transforms Our Lives']
# ['이미지의 삶과 죽음']
# ['비물질노동과 다중']
# ['의미의 논리']
# ['Gendering the Middle East: Emerging Perspectives']
# ['사물의 언어']
# ['Habitations of Modernity']
# ['Un barrage contre le Pacifique'
#  'Un barrage contre le Pacifique, Gallimard, Paris'
#  'Gauthier, Xavière, Les Parleuses, Les Editions de Minuit'
#  'Porte, Michelle, Les Lieux de Marguerite Duras'
#  'Gallimard, coll. "folio"' 'Yann Andréa Steiner' 'Ecrire']
# ['Identity, Youth & Crisis']
# ['소설의 이해']
# ['폭풍의 언덕']
# ['시학의 근본개념']
# ['Introduction", Raymond Williams: Critical Perspectives' '비평과 이데올로기']
# ['소설 속의 독자']
# ['장소와 장소상실']
# ['오리엔탈리즘']
# ['위험한 여성']
# ['Raymond Williams: Making Connections']
# ['만들어진 모성']
# ['노년기의 의미와 즐거움']
# ['Identity and the life cycle']
# ['소설의 이론']
# ['차라투스트라는 이렇게 말했다']
# ['거인과 바보들']
# ['Building positive self-concepts']
# ['라캉의 주체']
# ['From Fact to Fiction: Journalism & Imaginative Writing in America']
# ['시각과 시각성']
# ['사회를 보호해야 한다']
# ['현실/신경성 거식증-성과 계급 전이의 장소로서 여성 육체']
# ['집단심리학과 자아분석, In 문명속의 불만']
# ['예술, 문학, 정신분석']
# ['문명 속의 불만']
# ['문명속의 불만']
# ['히스테리 연구-프로이트 전집 4']
# ['정신분석학의 근본 개념']
# ['Gramophone, Film, Typewriter']
# ['가족, 사적 소유, 국가의 기원']
# ['Anatomy of Criticism: Four Essays']
# ['Translating Korea: Inaugural Lecture of the Young-Bin M in Chair in Korean Literature and Literary Translation']
# ['모파상 단편선 해설']
# ['근대문학의 종언']
# ['삶으로서의 은유']
# ['감정을 과학한다']
# ['공간의 시학']
# ['Marxism and the Interpretation of Culture']
# ['민족주의란 무엇인가']
# ['Narrative Discourse']
# ['Autobiography:Essays Theoretical and Critical']
# ['서사학이란 무엇인가' 'Narratology']
# ['Human Rights-Essays on Justification and Applications']
# ['현대성과 자아정체성 : 후기 현대의 자아와 사회']
# ['Decision-making in Professional Translation and Interpreting']
# ['Ageing without Agency: Theorizing the Fourth Age']
# ['안티 오이디푸스 : 자본주의와 분열증']
# ['Er-imagining Dementia in the Fourth Age']
# ['Topophilia and Topophobia: The Home as an Evocative Place of Contradictory Emotions']
# ['열정적 정치-감정과 사회운동']
# ['The Shape of the Past']
# ['Review: The Ethical Challenges of the TheoryEstablishment']
# ['정동이론']
# ['On Meaning: Selected Writings in Semiotic Theory']
# ['The Gift of the Other']
# ['에로스와 문명']
# ['서사학 강의' '서사학강의' '서사학 강의: 이야기에 대한 모든 것']
# ['서사학 강의' '서사학강의']
# ['A Model for Translation quality assessment'
#  'Translation quality assessment']
# ['Le vieux Jardin, Jeong Eun-Jin et J. Batilliot, Cadeilhan,Zulma']
# ['La Petite Ourse, Choi Mikyung et J.-N. Juttet, Paris, Le Serpent ?plumes']
# ['Christian Sorace., Afterlives of Chinese Communism :Political Concepts from Mao to XI']
# ['문예사회학']
# ['문화, 이데올로기, 정체성: 스튜어트 홀 선집' '문화연구 1983']
# ['Cohesion in English']
# ['While the U.S. Talks of War, South Korea Shudder']
# ['The Forms of Historical Fiction']
# ['도시의 정치경제학']
# ['Internal Colonialism: The Celtic Fringe in British National                             Development']
# ['현대세계의 일상성' '공간의 생산']
# ['장르론']
# ['Michel Ballard et Lance Hewson']
# ['literature, marxism and cultural materialism']
# ['Definition of Community : Areas of Agreement']
# ['The Mother/Daughter Plot']
# ['In her Motherʹs House: The Politics of Asian American Mother‐Daughter Writing']
# ['The Time Bind']
# ['the Topophilia and Topophobia symposium']
# ['From Motherhood to Maternal Subjectivity']
# ['페미니즘, 왼쪽 날개를 펴다']
# ['라캉읽기']
# ['Social gerontology: A multidisciplinary perspective']
# ['How do We Know when a Translation is Good?, In Exploring Translation and Multilingual Text Production: Beyond Context']
# ['A Model for Translation Quality Assessment']
# ['COSB – A Model for Translation Quality Analysis & Evaluation']
# ['수면혁명']
# ['페미니즘 이론 사전']
# ['프랑스 혁명의 가족로망스']
# ['포스트모더니즘의 이론과 전략']
# ["La gare de Sap'ong"]
# ['하나이지 않은 성']
# ['알츠하이머병 : 가족에게 다가가기']
# ['사르트르의 상상계']
# ['환경윤리의 이론과 전망']
# ['감정의 거시사회학 – 감정은 사회를 어떻게 움직이는가?']
# ['Successful Aging']
# ['문학에 대하여']
# ['신데렐라 서사, 오이디푸스 콤플렉스에서 신데렐라 콤플렉스까지']
# ['The Word Processor, Paper Machine']
# ['자크 라캉 세미나 11; 정신분석의 네 가지 근본 개념']
# ['La Mésentente']
# ['Autobiography:Essays Theoretical and Critical']
# ['The Question of German Guilt']
# ['기호의 정치경제학 비판' '시뮬라시옹']
# ['Vocabulaire de La Psychanalyse']
# ['Perdre de vue']
# ['Catharsis et Séries télévisées']
# ['Dress, Distress and Desire clothing and the female Body in Eighteenth-century Literature']
# ['Anti-Americanism in European Literature']
# ['여자가 없다고 상상해봐  : 윤리와 승화']
# ['Sacred Interconnections: Postmodern Spirituality, Political Economy, and Art']
# ['Gender and the Historian']
# ['재난 불평등-왜 재난은 가난한 이들에게만 가혹할까']
# ['Remembering James Olney-James Olney and the Study of Autobiography']
# ['시치료']
# ['Nationalism']
# ['문화와 권력으로 본 도시탐구']
# ['Foregrounded Description in Prose Fiction: Five Cross-Literary Studies']
# ['Bibliotherapy']
# ['페미니즘 이론']
# ['The child is Mother of the Woman: Exchange between Age and Youth in Doris Lessing']
# ['젠더 트러블\uf000' 'Psychic Life of Power:Theories in Subjection']
# ['검은 태양 - 우울증과 멜랑콜리' 'New Maladies of the Soul'
#  'Revolution in Poetic Language']
# ['페미니즘과 문학']
# ['행복, in 캐서린 맨스필드 단편선']
# ['La maison dans la cour du bas, J. BYON-ZIEGELMEYER'
#  'Le voyage de Monsieur Lee, J. Golfin et Hye-young Tcho, Arles, Picquier']
# ['시점의 시학(The Narrative Act ; Point of View in Prose Fiction)']
# ['性의 政治學: 上']
# ['언어예술작품론']
# ['모든 여성은 같은 투쟁을 하지 않는다']
# ['Les Interactions verbales tome I' 'Les Interactions verbales tome II']
# ['Image of the City']
# ['Journey to Mujin in Journey To Mujin: Anthology of Korean Short Fictions,'
#  'Record of a Journey to Mujin in A Washed-out Dream']
# ['A Journey To Mujin in Modern Korean Literature']
# ['Contested Embrace: Transboder Membership Politics in Twentieth-Century Korea']
# ['American Images Reflected in Korean Novels']
# ['A Washed-out Dream']
# ['Sexueller, Missbrauch: Überblick zu Forschung, Beratung, Therapie']
# ['세상은 왜 날씬한 여자를 원하는가']
# ['역사와 현실변증법']
# ['페미니즘과 문학']
# ['공포의 권력']
# ['공포의 권력']
# ['Translation Today; Trends and Perspectives']
# ['A Handbook of Critical Approaches to Literature']
# ['해방공간 4대신문']
# ['Sourciers et ciblistes'
#  '(En)Jeux esthétiques de la traduction, Étique(s) et pratiques traductionnelles']
# ['Information structure and sentence form - topic, focus, and the mental representations of discourse referents']
# ['Literary Translation: A Practical Guide' 'A Practical Guide']
# ['지각의 현상학']
# ['시점의 시학']
# ['정신분석사전']
# ['Self-concealment: Conceptualization, Measurement, and Health Implications']
# ['Handbook of aging and the social sciences']
# ['기호와 기계']
# ["Duras ou le poids d'une plume"]
# ['번역의 오늘: 해석이론']
# ["La Traduction Aujourd' Hui (번역의 오늘)"]
# ['Self-Starvation in Context: Towards a Culturally Sensitive, Understanding of Anorexia Nervosa']
# ['Translating Literature: Practice and Theory in a Comparative LiteratureContext']
# ['자서전의 규약']
# ['자서전의 규약']
# ['가부장제의 창조']
# ['Translation and original: Similarities and Dissimilarities, I']
# ['Pragmatics']
# ['City Signs: Toward a Definition of Urban Literature']
# ['(Re)constructing Reality']
# ['Critical Theory Today']
# ['Speculum of the Other Woman']
# ['Rekonstruktion nar-rativer Identitat(이야기분석)']
# ['The Korean grandmothers who sell sex']
# ['feminism and the politics of reading']
# ['젠더, 정체성, 장소']
# ['바흐찐의 소설 미학']
# ['기원의 소설, in 소설의 기원']
# ['아우렐리우스 명상록/키케로 인생론']
# ['모더니티의 다섯 얼굴']
# ["Problems of Dostoevsky's Poetic"]
# ['계몽의 변증법']
# ['Expressions idiomatiques en anglais et en fran?is']
# ["Traduire sans trahir, Lausanne, l'Age d'homme"]
# ['Po?ique du traduire']
# ['Les belles infid?es']
# ['Modernism: A Guide To European Lierature 1890-1930']
# ['자본과 정동']
# ['Reconfigured Spheres-Feminist Exploration of literary space']
# ['기억․서사']
# ['에코페미니즘' '가부장제와 자본주의']
# ['가부장제와 자본주의']
# ['Vivir para contarla(이야기하기 위해 살다)']
# ['시민권과 복지국가']
# ['공부를 넘어 교육으로']
# ['자살백과']
# ['Towards a Speech Act Theory of Literary Discourse']
# ['공간, 장소, 젠더']
# ['정동 정치']
# ['Track Changes : A Literary History of Word Processing']
# ['Sociologie et anthropologie']
# ['Rethinking Anti-Americanism']
# ['Introduction to Educational Gerontology']
# ['The ‘neglected night’: an emboided conceptual framework for the sociological study of sleep']
# ['Phénoménologie de la perception']
# ['Pour la poétique II']
# ['Magic and Modernity: Interfaces of Revelation and Concealment']
# ['Disease and the Novel 1880-1960' 'Disease and Novel 1880～1960']
# ['임상의학의 탄생' '자기의 테크놀로지']
# ['Kathryn Hamer and Lorraine Code, The Sex of Knowing']
# ['에코페미니즘' '가부장제와 자본주의']
# ['자본주의 도시와 근대성']
# ['Dialogic Imagination']
# ['The Anatomy of Disgust']
# ['성 정치학']
# ['경계없는 페미니즘']
# ['The Culture of Pain']
# ['문학과 페미니즘']
# ['Les Belles Infidèles']
# ['Introducing Translation Studies: Theories and Applications'
#  'Introducing Translation Studies']
# ['Hateship, Friendship, Courtship, Loveship, Marriage']
# ['누가 슬라보예 지젝을 미워하는가']
# ['Ecology, In Community and Lifestyle']
# ['Desire and domestic fiction']
# ['Contours of a Spatialized Politics : Homeless Vehicles and the Production of Geographical Scale']
# ['A textbook of Translation'
#  'The Translation of Metaphor, In  The Ubiquity of Metaphor: Metaphor in Language and Thought'
#  'Approaches to Translation']
# ['황석영 문학에 나타난 베트남전쟁 : 『무기의 그늘』을 중심으로']
# ['Rumor, Gossip and Urban Legends']
# ['Towards a Science of Translation']
# ['The Theory and Practice of Translation']
# ['Charles Russell Taber. The theory and practice of translation']
# ['Toword of Translating with special to principles and procedures involved in Bible translating']
# ['The Geography of Thoughts : How Asians and Westerners Think Differently ... and Why']
# ['비평의 해부']
# ['여성의 몸 여성의 지혜']
# ['Out of Solitude: Three Mediations of the Christian Life']
# ['시적 정의' '혐오와 수치심' '감정의 격동 1, 2, 3']
# ['Woman and Human Development, The Capabilities Approach']
# ['Monsieur Maeng marie sa fille, Han Yumi et H. Pejaudier']
# ['Freud, coll']
# ['기억의 지도']
# ['Fat Is a Feminist Issue: the Anti-Diet Guide for Women']
# ['인간과 공간']
# ['The Victorian Novel']
# ['Le piquet de ma m?e, Kang Gobae, H. Lebrun, Arles, Actes Sud']
# ['Hospital Room 205 and Other Korean Short Stories']
# ['My Very Last Possession And Other Stories by Pak Wansõ']
# ['Granny Flowers In Those Heartless Days, My very Last Possession: And Other Stories by Park Wanso'
#  'A Pasque-Flower on that Bleak Day, The Rainy Spell and Other Korean Stories']
# ['TORN IN TWO : The Experience of Maternal Ambivalence']
# ['남과 여, 은폐된 성적 계약']
# ['권력의 병리학']
# ['r, Anti-Americanism: Irrational and Rational']
# ['Learning to Labor']
# ['In Broad Daylight: Movies and Spectators After the Cinema']
# ['우울증에 반대한다']
# ['Realization of generativity in two samples of women at midlife']
# ['Le sujet de la philosophie']
# ['구별짓기  상․하']
# ['CONTROVERSIES IN ENVIRONMENTAL SOCIOLOGY']
# ['Intertextuality and the Discourse Community']
# ['Radical Pragmatics']
# ['서사론 사전']
# ['Language, semantics and ideology']
# ['페미니즘과 지리학']
# ['하이테크네']
# ['릴케 시선']
# ['남성성/들']
# ['감정과 이성']
# ['낭만적 거짓과 소설적 진실']
# ['미국인의 사고와 관습']
# ['Mothers and Other Clowns: the Stories of Alice Munro']
# ['Pragmatics and linguistics: An analysis of sentence topics']
# ['Translation Criticism : The Potentials and Limitations'
#  'Translation Criticism - The Potentials and Limitations'
#  'The Potentials and Limitations']
# ['장소와 장소상실']
# ['선택이라는 이데올로기']
# ['추리소설']
# ['Of Woman Born']
# ['Oneself As Another']
# ['타자로서 자기자신' '시간과 이야기1']
# ['시간과 이야기 1(Temp et recit Ⅰ)']
# ['The European Dream : How Europe’s vision of the Future is quietly eclipsing the American Dream']
# ['Anxiety and Stigma in Dementia: A Threat to Aging in Place']
# ['Beyond Feminist Aesthetics']
# ['서사의 본질']
# ['Stephen Crane, Journalism, and the making of Modern American Literature']
# ['Psychology a study of a science, Vol.3']
# ['사람-중심-상담']
# ['Feminism Meets Queer Theory']
# ['The Stages of Economic Growth : a Non-Communist Manifesto']
# ['Narrative Fiction and Reality']
# ['Topophilia and Topophobia: Reflections on 20th Century Human Habitat']
# ['Literature and Ecology, In The Ecocriticism Reader']
# ['친밀한 살인자']
# ['Space in Theory']
# ['Critical Studies : The Pregnant Text : Bakhtin’s Ur-Chronotope']
# ['Handbook of the psychology of aging']
# ['정신분석학의 근본 개념' '프로이드 정신분석학 입문']
# ['극과 극적 요소']
# ['이야기와 담론']
# ['문명속의 불만' '정신분석입문']
# ['La place du proverbe dans la theorie de la traduction']
# ['박완서와 츠쯔젠 소설에 나타난 노년현상의 비교연구']
# ['Talgung, Maryse Bourdin, Lee In-Sook et Kim Kyunghee']
# ['Culture and Imperialism']
# ['Orientalism']
# ['말년의 양식에 관하여']
# ['주디스 버틀러의 철학과 우울']
# ['Deeper than Deep Ecology']
# ['푸코와 치아']
# ['The Art of Translation']
# ['Approaches to Discourse']
# ['정치적인 것의 개념' '정치신학-주권론에 관한 네 개의 장']
# ['자본주의, 사회주의, 민주주의']
# ['불평등의 재검토']
# ['짓기와 거주하기']
# ['영화와 소설의 서사구조-이야기와 담론']
# ['Can Literary Style be Translated']
# ['Ugly Feelings']
# ['쇼트 : 영화의 시작']
# ['정신분석 강의 : 하']
# ['혁명의 영점']
# ['짐멜의 모더니티 읽기']
# ['Five Appro-aches of literary Criticism']
# ['제2의 性: 상']
# ['제2의 성 (상)']
# ['이데올로기의 숭고한 대상']
# ['Violence']
# ['There Is No Place Like Home: Belonging and Placelessness in the Postmodern Novel']
# ['The Vegetarian']
# ['Translation Studies: An integrated Approach']
# ['야성의 삶']
# ['은유로서의 질병']
# ['Autofiction(s): Colloque de Cerisy 2008']
# ['에티카']
# ['개정판 에티카']
# ['Can the Subaltern Speak?, In Marxism and the Interpretation of Culture'
#  '서발턴은 말할 수 있는가?']
# ['소설의 이론']
# ['The Spiral Dance: A Rebirth of the Ancient Religion of the Great Goddess']
# ['스피박 넘기']
# ['세계철학사']
# ['Place and Identity in Cultural Studies: Confessions of a Revised Postmodern Criti']
# ['Discourse Analysis - The Sociolinguistic Analysis of Natural Language']
# ['꿈의 세계와 파국 - 대중 유토피아의 소멸']
# ['은유로서의 질병']
# ['Coming Unstrung: Women, Men, Narrative, and Priciples of Pleasure']
# ['A Little History of Literature']
# ['Greater emotional empathy and prosocial behavior in late life']
# ['Joy Luck Club']
# ['불안한 현대사회']
# ['문학비평 : 반영이론과 생산이론']
# ['The Theory of the Leisure Class']
# ['어머니의 신화']
# ['Ageism : Prejudice Against Our Feared Future Self']
# ['산문의 시학']
# ['The Poetics of Prose']
# ['Sexual / Textual Politics']
# ['Descriptive Translation Studies and Beyond']
# ['TOPOPHILIA' '공간과 장소' '토포필리아']
# ['CRITICAL THEORY TODAY']
# ['French Litetary Theory Today']
# ['Community and Civil Society']
# ['움베르토 에코의 문학 강의']
# ['가부장제와 자본주의']
# ['위험사회']
# ['Journalism and The Novel: Truth and Fiction, 1700-2000']
# ['아파트 공화국\uf000']
# ['아파트 공화국']
# ['The Informational component']
# ['아파트 공화국' '한국의 아파트 연구']
# ["The Translator's Invisibility : A History of Translation"
#  "The Translator's Invisibility"
#  'The Translator’s Invisibility: A History of Translation'
#  "The Translator's Invisibility : a History of Translation"]
# ['Stylistique comparée du français et de l’anglais']
# ['Marguerite à Duras, édition n〬 1']
# ['Dickens, Reade and Collins, Sensation Novelist']
# ['알츠하이머 치매의 예방과 치료']
# ['경제성장의 제단계']
# ['성 정치']
# ['미학이론']
# ['가부장제 이론']
# ['가부장제이론' '가부장제 이론']
# ['Terrifying Love']
# ['Orality and Literacy-The Technologizing of the Word']
# ['Ecofeminist Philosophy']
# ['So far from the bamboo grove']
# ['거부당한 몸']
# ['R Writing in Society']
# ['The Country and the City' 'The Country And the City'
#  'Resources of Hope: Culture, Democracy, Socialism'
#  'Raymond Williams on Television: Selected Works'
#  'The Raymond Williams Reader']
# ['Fontana Paperbacks']
# ['Communications(3rd Ed.)']
# ['Maturation Process and Facilitating Environment']
# ['Literature']
# ['Memory and the Ethnic Self: Reading Amy Tanʹs Joy Luck Club']
# ['Style Is the Relationship: A Relevance-theoretic Approach to the Translator’s Style']
# ["L'harmonium, Kang Gobae et Son Mi-kyung, Arles, Actes Sud"]
# ["Une fille nomm? deuxi?e gar?n, CH'OE Yun, P. Maurus"]
# ['La mousson, Cathy Rapin, Hye-Gy?g Im, Gemenos, Autres temps'
#  "Los Angeles d'un r?eur, Jean Golfin, Tcho Hye Young & Li Jin Mieung, Arles, Phililppe, Picquier"]
# ['China’s Consumers Show Growing Influence in Gold Market']
# ['공간과 장소' '토포필리아']
# ['Constructing the Other: A Critical Reading of The Joy LuckClub']
# ['Une étude sur les termes d’adresse pour la traduction français-coréen']
# ['젠더와 민족']
# ["L'autobiographie"]
# ['Affective encounters: tools of interruption for activist media practices']
# ['친밀성의 거래']
# ['Fictions']
# ['여성․문화․사회']
# ['불가능한 것의 가능성']
# ['쓰레기가 되는 삶들' '지구화, 야누스의 두 얼굴' '부수적 피해']
# ['≪무소의 뿔처럼 혼자서 가라≫' '<꿈꾸는 인큐베이터> ≪한말씀만 하소서≫']
# ['Introduction to Text Linguistics']
# ['어머니의 신화']
# ['Looking awry' 'The sublime object of ideology']
# ['人生論']
# ['전쟁과 희생: 한국의 전사자 숭배']
# ['全球化视域里的中国性别诗学研究']
# ['發情裝置']
# ['歷史とトラウマ']
# ['現代中国の産業: 勃興する中国企業の強さと脆さ']
# ['翻译的社会性研究']
# ['韓國戰後問題詩集']
# ['二十世纪女作家生命意识与性别诗学的构建']
# ['张洁研究专集']
# ['열녀전']
# ['치매와 마주하기']
# ['韓國 現代 成長小說 연구']
# ['樹州·卞榮魯文選集']
# ['审美特性']
# ['大トルストイ全集 第十五卷']
# ['本日の, 吉本ばなな']
# ['新修シェークスピヤ全集, 第15卷']
# ['文學翻譯比較美學']
# ['女性主义与现代文学的性别主体性叙事']
# ['한국소설에 나타난 제국주의 욕망 탐구']
# ['박완서(朴婉緒)와 장결(張潔)소설에 나타난 페미니즘 비교 연구']
# ['孫晋泰先生全集 6']
# ['소설 <엄마의 말뚝>과 <무자>의 어머니상 비교연구 : 중한 여류작가의 경우']
# ['노천명 시 연구']
# ['新民族主義와 新民主主義']
# ['時調詩學']
# ['トルストイ全集, 第六卷']
# ['グロ-バリズムへの叛逆-反米主義と 市民運動']
# ['‘專業的 主婦’の 主體形成']
# ['플라나리아']
# ['기억, 서사(記憶, 物語)' '기억 서사']
# ['玄德의 童話와 少年小說 연구']
# ['白頭山覲參記']
# ['沈熏 소설 연구']
# ['海外 抒情詩集']
# ['モノ誕生｢いまの生活｣: 1960-1990 : 日本人の暮らしを変えた133のモノと提案']
# ['自然之蛙、图腾之娲和生命之蛙—莫言小说『蛙』的意象分析']
# ['汤显祖和莎士比亚的女性观与性别意识']
# ['抗日战争及伟大意义']
# ['张洁研究资料']
# ['1960-1970년대 한국 아파트의 변천에 관한 연구']
# ['張洁文集：中短篇小說']
# ['论莫言小说『蛙』中的“蛙”与“猫头鹰”意象的民族意味']
# ['개항기 목포 이주 일본인의 도시 건설과 도시 생활']
# ['慶南年鑑 창간호' '慶南年鑑 제2호']
# ['반응 중심 문학교육의 방법 연구']
# ['歌辭의 存在樣式 硏究']
# ['80年代中國與韓國女性作家比較論 : 以張潔和朴婉緒為個案的研究']
# ['文章講義']
# ['斎藤真理子の韓国現代文学入門(4): 韓国文学の重鎮パク・ワンソに見る 女性たちの体験した朝鮮戦争']
# ['20世纪中国女性文学史']
# ['翻译的文化参与']
# ['韓國時調大事典 上·下']
# ['那么多的酸模都讓誰吃了' '那么多的草叶哪里去了？' '小說集孤獨的你']
# ['非常久远的玩笑' '那个男孩的家']
# ['多情佛心' '韓國文學全集 5 錦衫의 피·多情佛心' '月灘朴鍾和文學全集 10 多情佛心']
# ['沈熏 小說 硏究']
# ['朴龍喆全集 第二卷']
# ['中国现代文学的性别意识']
# ['耽羅紀行 漢拏山']
# ['無序錄' '李泰俊 文學全集 隨筆集 無序錄']
# ['朝鮮文學硏究鈔']
# ['比较文学概论']
# ['朴婉绪小说汉译考略, In 外国语言文学研究（第2辑)']
# ['歷代歌辭文學全集1-30']
# ['一石激起千层浪-关于性别诗学批评的思考' '女性文学研究、性别诗学与社会学理论' '性别诗学：意会与构想']
# ['일본 근대문학의 기원']
# ['ゴールドラッシュ' '여학생의 친구' '루주' '월의 저편 상, 하' '비와 꿈 뒤에' '우에노 역 공원 출구']
# ['舊殼을 버셔요-']
# ['世界奇文選']
# ['朴婉緒小說漢譯研究']
# ['帝國日本と植民地都市']
# ['호텔 로열']
# ['朝鮮 18世紀 奴婢實態와 推奴策']
# ['儒家夫妇观及其当代价值']
# ['蛙鸣中的生命欢唱——论莫言小说『蛙』中的意象']
# ['浅析中国老年文学的现状及其发展']
# ['蛙鸣中的悲剧——莫言『蛙』中的意象小识']
# ['林巨正 第一卷-義兄弟篇(1)-']
# ['なぜ韓国文学ブーム？ フェミニズム文学で注目の若き女性作家たち']
# ['莫言小说意象的多重意蕴——『蛙』和『红高粱家族』的意象分析']
# ['日本語を書く方法／装置のメディア社会学的研究一手書き、タイプライタ一、キ一ボ一ド入力の事例考察を中心に']
# ['沈熏 小說 硏究']
# ['古時調新釋-附 作者傳-']
# ['마사지사  : 비페이위 장편소설']
# ['水浒传与红楼梦的性别诗学研究']
# ['중독']
# ['発明特許の日本史']
# ['4TEEN' '6TEEN']
# ['蛙']
# ['박완서와 张洁 소설의 모녀관계 변화 양상 비교 연구 : ‘父 부재’ 형 소설을 중심으로']
# ['论莫言小说『蛙』中的“蛙”意象']
# ['第二性∥']
# ['大漢和辞典']
# ['翻譯硏究詞典']
# ['张洁研究专集']
# ['论莫言小说中动物意象在叙事中的流变']
# ['反未主義']
# ['文化翻译策略的多样性与多译本互补研究']
# ['1930年代 韓國 短篇小說 硏究 : 缺乏狀況의 兩面性을 中心으로']
# ['翻译中文化因素的处理：异化与归化,（人文社会科学版）']
# ['金天澤 硏究']
# ['散文(附譯詩)']
# ['珍本 靑丘永言']
# ['鄭芝溶硏究' '정지용 전집 2 산문']
# ['노인 무력감의 현상연구']
# ['高麗歌詞' '原本春香傳']
# ['風流의韓國']
# ['海東歌謠 附永言選']
# ['《소학생》誌 연구 : 童話 및 少年小說을 중심으로']
# ['朝鮮女流漢詩選集 꽃다발' '투르게네프 散文詩']
# ['박경리 소설의 여성성 연구']
# ['안수길 소설의 공간모티프 연구 : 「통로」·「성천강」을 중심으로']
# ['朴景利의 『土地』 연구 : <三代談>의 葛藤構造를 중심으로']
# ['金東仁短篇選 第1卷']
# ['韓國現代小說에 나타난 女性의 自覺意識 考察']
# ['憧憬']
# ['崔曙海 소설 연구 : 부권부재 의식을 중심으로']
# ['韓國近代飜譯文學史硏究']
# ['諺文 朝鮮口傳民謠集' '朝鮮民謠選']
# ['注解歌辭文學全集']
# ['中韓文壇兩道絢麗風景 : 張潔底朴婉緒早期女性小說代表作比較研究']
# ['金起林 全集 2']
# ['村上春樹クロニクル1983-1995']
# ['딩씨 마을의 꿈  : 옌롄커 장편소설']
# ['对莫言小说『蛙』中蛙之意象的再分析']
# ['一部女人的历史-张洁长篇小说《无字》研究']
# ['中國當代文學作品精選(1949-1999)・中篇小說卷']
# ['韓國雜誌總攬\xad韓國雜誌70年史']
# ['人生散文']
# ['한‧중‧일 인터넷 세대가 서로 미워하는 진짜 이유']
# ['成长如蜕-二十世纪九十年代女性成长小说研究']
# ['关于\uf000红楼梦\uf000韩译本中称谓语的若干问题']
# ['莫言小说中的动物意象']
# ['『蛙』中的隐喻研究']
# ['戰時期日本の精神史: 1931-1945']
# ['校注 海東歌謠']
# ['于民间升腾的意象—论莫言小说中的动物魔幻意象']
# ['독식비판-지식 경제 시대의 부와 분배']
# ['윤리 21' '윤리21' '일본 근대문학의 기원' '일본근대문학의 기원']
# ['이야기 분석']
# ['공간의 시학']
# ['서발턴은 말할 수 있는가(서발턴 개념의 역사에 관한 성찰들)' '다른 세상에서']
# ['사죄와 망언 사이에서']
# ['근대 일본의 전쟁 논리']
# ['현대소설에 나타난 노인부양문제 해결을 위한 사회사업적 접근-박완서 단편소설을 중심으로']
# ["여성 성장소설 연구 : '아버지 부재' 모티프를 중심으로"]
# ['서울 지하층 주거의 형성과 변화에 관한 연구']
# ['생애주기별 자살현황과 요인 및 예방에 관한 연구 : 청소년층·장년층·노년층 자살을 중심으로']
# ['소곰']
# ['박경리 『토지』의 여성인물연구']
# ['박정희 시대와 중동건설2']
# ['한국인의 커뮤니케이션에 나타난 공손전략']
# ['포스트모더니즘 비판']
# ['‘언표’로서의 내면－1990년대 문학사의 비판적 재구성을 위한예비적 고찰들－'
#  '반시대적 고찰 1980년대 ‘문학과지성’과 『우리 세대의 문학』']
# ['고쳐 쓴 한국 현대사']
# ['한중일 청년을 말하다']
# ['몸의 심리신체성과 병든 몸의 자아']
# ['현단계 노동문학의 여성문제 인식 : 올바른 여성문학의 정립을 위하여']
# ['우울증 서사로 보는 <콩쥐팥쥐> · <상사뱀> · <고분지통>']
# ['유하 시에 나타난 장소성 연구']
# ['박완서 소설 연구 : 자전적 성장소설을 중심으로']
# ['우리 소설의 일탈과 지향']
# ['｢영웅소설의 형성과 변모양상 연구｣']
# ['고민하는 힘' '오리엔탈리즘을 넘어서']
# ['일제강점기 근대시설의 모더니즘 수용 : 박람회·보통학교·아파트 건축을 중심으로']
# ['90년대 문학 어떻게볼 것인가']
# ['숲속의 방' '밤과 요람' '사과를 따지 않은 이브' '순례자의 노래' '이사' '저 절로 가는 사람' '청색시대']
# ['달라진 선택' '교정의 륜리, In 진군길' '생활탐구와 소설창작' '창작수업' '청춘']
# ['현대사가 만들어낸 비극, 이산가족-길소뜸과 비단구두' '피아골과 남부군－빨치산에 대한 극단적인 두 시선']
# ['‘아카’(アカ)와 ‘빨갱이’의 탄생—‘적(赤-敵) 만들기’와 ‘비국민’의 계보학'
#  '작은 ‘한국전쟁’들-평화를 위한 비주얼 히스토리']
# ['한국영화사 공부: 1980~1997']
# ['늙음과 돈으로 보는 플라톤의 정의론－ 『국가』 제1권을 중심으로 －']
# ['일상생활의 패러다임?현대 사회학의 이해']
# ['어머니와 딸 그리고 가부장(제)의관계 변화의 양상 －박완서의 「엄마의 말뚝」 연작과 김애란의 「칼자국」을 중심으로－']
# ['서사의 시간구조와 시간순서연구- 오정희의「옛우물」을 중심으로 -']
# ['녹색지대와 애드벌룬' '눈물' '희화(戱畵)' '여정(旅情)' '강신재 소설 선집']
# ['감정수업' '철학VS철학']
# ['1960년대 신문연재소설의 아버지 이미지']
# ['죽음학 강의']
# ['부림지구 벙커X']
# ['타인의 얼굴' '타인의 얼굴-레비나스의 철학' '고통의 현상학-박완서의 <한 말씀만 하소서>']
# ['한국 역사소설의 재인식' '현대소설 上']
# ['창의성과 비판적인 사고능력 개발을 위한 고전읽기 수업방안 연구 - 문학토론을 통한 <명저읽기> 수업사례를 중심으로']
# ['한국전후소설에 나타난 모성성 연구 - 박완서의 엄마의 말뚝 연작을 중심으로 -' '우리어문연구'
#  '전쟁 체험의 한 수용 양식―하근찬론' '박완서 작품에 나타난 한국전쟁의 기억과 주체의 형성']
# ['광인일기' '귀향 in: 새농민' '가을의 귀로 in: 새농민']
# ['소설 『최후의 증인』의 영화화 양상과 한국 추리 서사에 재현된 법(法)의 문제- 영화 <최후의 증인>(1980)의 검열 양상과 관련하여 -']
# ['신문 사설 텍스트의 주제와 주제 전개에 관한 연구']
# ['전체주의적 반공주의와 순수.참여 논쟁']
# ['인문치료']
# ['다큐멘터리 <모래 My Father’s House>']
# ['한국문학과 모성성']
# ['자전적 서사의 서술기법과 공감의 문제 －박완서 「엄마의 말뚝1」과 황순원 「곡예사」를 중심으로－' '타인을 앓다'
#  "장정일 <아담이 눈 뜰 때>에 나타난 '미성년'의 의미" '살아 있는 날의 시작' '오정희 소설에 나타난 ‘걷기’의 의미']
# ['최인호 소설에 나타난 집과 도시의 공간성 연구']
# ['글쓰기치료에 관한 이론적 고찰']
# ['조선 후기 한성부 상류주택 안채의 건축 특성에 관한 연구']
# ['박완서 소설에 나타난 도시와 모성' '"도시의 흉년"에 나타난 70년대의 서울, In 박완서 소설에 나타난 도시와 모성'
#  '박완서의 소설에 나타난 도시의 양상(3)' '박완서의 소설에 나타난 도시의 양상 (3)' '박완서론'
#  '박완서의 소설에 나타난 도시의 양상(3):『도시의 흉년』에 나타난 70년대의 서울'
#  '박완서 론-｢울음소리｣와 ｢닮은 방들｣, ｢포말의 집｣의 비교 연구' '박완서 소설에 나타난 도시와 모성\uf000'
#  '박완서 소설에 나타난 도시의 양상, In  박완서론'
#  '박완서의 소설에 나타난 도시의 양상(3): ｢도시의 흉년｣에 나타난 70년대의 서울']
# ['한국여성노동자운동사 2' '여성주의와 여성운동, 여성노동자운동']
# ['저항과 투항-군사정권들과 종교' '전쟁의 기억, 기억의 전쟁' '전쟁과 희생']
# ['신경림 시의 서사성 연구']
# ['서구적 시각을 통한 박수근의 ‘정전화’와 그 과정']
# ['한국현대사 산책-1970년대편 : 평화시장에서 궁정동까지' '한국 현대사 산책 2권' '한국현대사산책 1990년대편 1권'
#  '자동차의 미디어 기능에 관한 연구 : 자동차는 한국인의 국가․사회 정체성 형성에 어떤 영향을 미쳤는가?'
#  '한국현대사 산책-1970년대 편 3권' '강남, 낯선 대한민국의 자화상'
#  '한국 현대사 산책 1970년대 편 3권: 평화시장에서 궁정동까지' '전화의 역사' '대중매체 이론과 사상' '한국대중매체사'
#  '한국현대사산책 1970년대편 : 평화시장에서 궁정동까지' '한국 현대사 산책 1980년대편 1권'
#  '한국 현대사 산책 1980년대편 2권' '한국 현대사 산책 1990년대편 1-3당합당에서 스타벅스까지'
#  '6·25전쟁에서 4·19 전야까지']
# ['학습자 중심 소설교육 방안연구 : 양귀자의 『원미동 사람들』을 중심으로']
# ['문학을 부수는 문학들']
# ['수평으로 함께 잠겨보려고']
# ['제국을 향한 모델 마이너리티의 자기 고백']
# ['발톱 빠진 독수리들']
# ['북한의 항일무장투쟁 전통과 민족 만들기-민족주의와 권력, 담론, 주체']
# ['반공주의와 자전소설의 형식 - 박완서를 중심으로 -'
#  '전쟁기의 증언과 반공주의의 규율 - 박완서 『목마른 계절』의 개작 양상 -'
#  '기억 속의 공간과 체험의 서사 ― 박완서의 「그 여자네 집」을 중심으로'
#  '기억 속의 공간과 체험의 서사 ― 박완서의 ｢그 여자네 집｣을 중심으로'
#  '기억 속의 공간과 체험의 서사  ― 박완서의 ｢그 여자네 집｣을 중심으로' '현대소설과 분단의 트라우마'
#  '전쟁의 상처와 유년의 향수' '반공주의와 자전소설의 형식 - 박완서를 중심으로'
#  '전후 세태와 소설의 존재방식-정비석의 <자유부인>을 중심으로' '동경과 좌절의 미학―이태준론' '반공주의의 소설?사회학적 기능'
#  '?공복사회의 실상과 원칙주의자의 신념?' '근대화의 부정성과 본원적 인간, 김정한-대쪽 같은 삶과 문학'
#  '민족사로 승화된 가족사의 비극']
# ['토픽으로 보는 1980년대의 출판계']
# ['만들어진 노년의 불행 : 시몬 드 보부아르의『노년』읽기'
#  '시몬 드 보부아르의 육체에 대한 윤리적 성찰 - 『제2의 성』을 향한 비판에 대한 재고찰']
# ['?한국 현대소설의 풍자성 연구?']
# ['‘유모어 소설’의 세계관과 웃음의 기법-1930~1950년대 ‘유모어소 설’을 중심으로']
# ['해방 30년의 한국문학 속에 나타난 미국의 대중적 이미지']
# ['여성주의 윤리 시각에서 본 여성의 모성']
# ['양주동의「近古東西奇文選」을 통해 본『문장』의 미의식']
# ['아파트 단지와 공룡, In 사람의 도시 : 도시문화론\uf000']
# ['서울대학교 대학신문, 중산층 의식을 진단한다' '중산층 의식을 진단한다']
# ['황순원 단편소설의 공간의식 연구']
# ['開城誌']
# ['역사 속의 페미니스트']
# ['현대노인학']
# ['바흐친의 산문학']
# ['소설의 이론' '영혼과 형식']
# ['짐멜의 모더니티 읽기' '돈의 철학']
# ['이은상 조두남 논쟁']
# ['경남문예총람']
# ['한국전쟁과 한국자본주의']
# ['가둔 여자와 갇힌 남자, 그들 사이에 있었던 180일 동안의 일!'
#  '양귀자 소설 영화판권경쟁 과열 “장사 되겠다” 30여 감독 사투벌여']
# ['｢빌헬름 마이스터의 수업시대-수업시대의 구성에 있어서 형성소설과 자전소설의 관계 및 이로니의 기능｣']
# ['영문학 교육과 연구의 과제들' '에코페미니즘- 페미니즘의 생태학과 생태학의 페미니즘'
#  '차이의 정치성과 여성 해방론의 현단계 현대비평과 이론']
# ['부실용역에 제주 문학관 건립사업 ‘지지부진’']
# ['정전의 해부' '저자/저자성의 문제 - 바르트와 푸코의 영향을 중심으로' '다문화시대의 문학 정전(正典)'
#  '교양소설 개념의 문제점 『빌헬름 마이스터의 수업시대』를 중심으로']
# ['청년문화, 혹은 소수문화론적 연구에 대하여']
# ['낭독공연을 통한 화법교육 방안']
# ['푸코 효과-통치성에 관한 연구']
# ['중학교 국어과 교사용 지도서-국어․생활국어 1-1']
# ['책을 만드는 사람들 30—또 하나의 문화']
# ['미국의 전횡적 힘의 논리를 전복시키는 우리소설, In 칼날 위에 서다' '문인사 기획전 4 지금 여기 박완서'
#  '‘황진이 서사’를 다룬 남과 북의 역사소설, 그 허구적 진실 - 홍석중과 김탁환의 ‘황진이 서사’를 중심으로'
#  '미국의 전횡적 힘의 논리를 전복시키는 우리 소설' '비평의 잉겅불']
# ['천황 히로히토는 이렇게 말하였다' '포스트콜로니얼']
# ['한국의 근대성, 그 기원을 찾아서-민족 섹슈얼리티 병리학' '한국의 근대성. 그 기원을 찾아서 - 민족, 섹슈얼리티, 병리학'
#  '여성성과 멜로, 그 은밀한 접속?' '나이듦 수업']
# ['치매노인의 심리증상과 케어']
# ['이데올로기와 신학']
# ['화폐, 마법의 사중주' '소수성의 정치학']
# ['몽테뉴《수상록》선집: 나이 듦과 죽음에 대하여']
# ['서사, 기억과 망각의 갈림길' '천상병평론' '비평과 전망' '비평, 90년대 문학을 묻다'
#  '서사, 기억과 망각의 갈림길 -박민규. 김영하. 성석제의 소설을 중심으로']
# ['한국전쟁과 패션의 국제화. in: 우리생활 100년, 옷']
# ['한국 반미문학사 서설, In 전쟁은 신을 생각나게 한다']
# ['한국 현대 환상 소설의 전략   ― 세계 접속과 실천 윤리']
# ['객지문학']
# ['1950년대']
# ['여성소설의 어제와 오늘, In 여성문학의 이해' '여성문학의 이해']
# ['이문구 소설에 나타난 근대성과 탈식민성 연구']
# ['가사집2']
# ['현대사회와 가족']
# ['한국 여성문학의 흐름-시와 소설을 중심으로' '소재주의를 넘어 새로운 인간성의 실현으로' '누가 홀로 술틀을 밟고 있는가'
#  '눈물꽃' '실락원 기행' '이 시대의 아벨' '초혼제' '예수와 민중과 사랑 그리고 詩' '우리시대 우리작가17: 박완서'
#  '여성해방의 문학' '다시 살아 있는 날의 지평에 서 있는 작가, 박완서' '또 하나의 문화: 여성해방의 문학 (3)'
#  '다시 살아 있는 날의 지평에 서 있는 작가' '70년대 여성 작가의 현주소' '또 하나의 문화 제2호'
#  '좌담: 페미니즘 문학과여성운동(일시: 1987년2월27일)' '고정희 시 전집 1·2']
# ['현대 페미니즘의 테제들']
# ['박경리 소설의 낭만적 특성 연구']
# ['상호작용의례 - 대면행동에 관한 에세이']
# ['휴대전화, 철학과 통화하다']
# ['현대시의 패러디와 장르 이론']
# ['소설사회학을 위하여']
# ['돌봄의 철학과 미학적 실천' '간호에서의 보살핌에 대한 철학적 탐구- 리쾨르(Ricoeur)의 이야기 윤리에 기초하여 -'
#  '리콰르의 이야기적 정체성과 생명윤리' '몸의 기억과 자기 정체성']
# ['명랑한 밤길' '피어라 수선화' '내 생의 알리바이' '내가 사랑한 여자' '공선옥, 마흔에 길을 나서다'
#  '사는 게 거짓말 같을 때' '술먹고 담배 피우는 엄마' '≪오지리에 두고 온 서른 살≫']
# ['정보인지 전략으로서 서사와 신뢰할 수 없는 서술(자)']
# ['오이디푸스적 시선 속에 동요하는 글쓰기, In 한국문학과 모성성' '역사소설의 양식과 이순신의 형성 문법'
#  '스캔들과 반공국가주의' '식민지 시기 야담의 오락성과 프로파간다'
#  '스캔들과 반공 -‘여류’ 명사 모윤숙의 친일과 반공의 이중주-'
#  '가난과 국가, 군국모의 연기하는 신체정치 - ‘나가라’의 전시모성과 일상의 신체 변용'
#  '박종화와 김동리의 자리, “반탁운동의 후예들”과 한국의 우파 문단' '이광수 복권과 문학사 기술의 관련 양상'
#  '한국 근대 역사소설의 장르론적 연구' '빨치산과 월남인 사이, ‘이승만’의 재현/대표성의 결여와 초과의 기표들'
#  '1958년 북한 발(發) ‘고아 구제’ 담화와 남한/일본에서의 북한행 역진 - 한국전쟁과 고아 심리/선전전 ①']
# ["일제의 의복 통제와 '국민' 만들기백의 탄압 및 국민복 장려를 중심으로"]
# ['채만식의 초기소설에 나타난 ‘가족과 자본’' '일제 강점기 민족문학 작가와의 대화: 염상섭, 채만식, 김사량']
# ['연합군 자료를 통해 본 버마의 일본군‘위안부’ 제도']
# ['존재는 눈물을 흘린다' '인간에 대한 예의' '<사랑하는 당신께> ≪인간에 대한 예의≫' '무소의 뿔처럼 혼자서 가라'
#  '상처 없는 영혼']
# ['한국 현대소설의 생태학적 연구 : 김동리·황순원 소설을 중심으로' '한국 현대소설과 생태학적 상상력']
# ['문학ㆍ사랑ㆍ가난']
# ['한국 항일문학 연구-심훈 소설을 중심으로']
# ['사토 아이코(佐藤愛子)와 朴婉緖 작품에 나타난 현대의 老人']
# ['탈주체적 등장인물 연구']
# ['박완서 소설의 여성상 변모 연구']
# ['강신재, 오정희, 최윤 소설에 나타난 여성성 연구'
#  '1970년대 신문연재소설의 여성 인물과 ‘연애’ 양상 연구:  『별들의 고향』, 『겨울여자』를 중심으로']
# ['박완서 소설에 나타난 가족관계의 양상']
# ['일상 속에 퇴적된 여성의 내면을 찾아서']
# ['정신분석학과 문학비평']
# ['최정희론']
# ['한국의 베트남전쟁 참전 재평가']
# ['문화적 애도와 민족공동체: 탈독재기 ‘애도문화론’을 위한 시론']
# ['한국문학 해외 소개의 현황과 과제: 세계화를 향해 걸어온 긴 여정, 그러나 아직은 먼 길'
#  '2000년 이후 한국문학 콘텐츠의 세계화 경험과 방향' '구보 박태원의 시(詩)연구']
# ['국어과 교육과정(교육과학기술부 고시 제2012-14호 [별책 5])' '국어과교육과정'
#  '교육과학기술부 고시 제2012-14호[별책 5]' '국어과 교육과정 교육과학기술부 고시 제 2012-14호 별책 5']
# ['국어과 교육과정(교육부 고시 제2015-74호 [별책 5])' '교육 50년사 : 1948∼1998']
# ['[단행본] 포스트 모더니티의 조건' '공간과 장소' '부르주아 유토피아: 교외의 사회사']
# ['80년대 한국 여성시 연구-고정희 시에 나타난 여성성 일탈 양상을 중심으로']
# ['80년대 우리문학을 결산한다: 양귀자의 『원미동 사람들』' '80년대 우리 문학을 결산한다; 양귀자의 『원미동 사람들』'
#  '김원일 깊이 읽기']
# ['데기-되기:『선천댁』에 나타난 안병무의 ‘민중 구원론’다시 읽기']
# ['모성의 수용 양상 : 신경숙과 공선옥의 소설을 중심으로'
#  "여성주의 시각에서 본 '집'의 의미 연구 : 박완서, 오정희, 배수아를 중심으로"]
# ['포유강 사람속']
# ['한국경제의 역사적 조명']
# ['심훈 문학 세계' '심훈의 <상록수> 고']
# ['드라마의 기법-고전비극의 이념구 구조']
# ['도시 속의 청년 ‘난민’: 청년들의 ‘방’ 거주 경험에 대한 문화적 분석을 중심으로']
# ['전쟁, 이주, 트라우마: 아시아계 글로벌 서사로서 이창래의 『항복한 자』']
# ['근대기 한국의 보들레르 시 번․중역과 그 함의 : 김억과 양주동의 설전을 중심으로']
# ['소설창작론' '문학교육론(개정판)' '현대소설론']
# ['채만식 소설에 나타난 근대여성주체와 모성의 문제']
# ['한국 정치적 현대성의 젠더화된 구조와 가내성(家內性)의 정치적 부상: 새로운 ʻ시민정치ʼ의 발생적 구조와 본성에 관한 시론(試論)']
# ['근대 독본 문화사 연구' '이문구 전집 16 : 그리고 기타 여러분']
# ['한국 현태생태담론과 이론연구' '한국 현대 생태담론과 이론 연구' '한국현대소설과 에콜로지즘'
#  '한국 현대 소설에 나타나는 에코페미니즘(Eco-Feminism)']
# ['결혼이주여성의 문화적응 스트레스와 한국인에 대한 인식']
# ['문학적 현실의 전개']
# ['한국의 중산층을 다시 생각한다' '한국 노동계급의 형성']
# ['안개의 肖像' '광상곡' '호수공원' '여름' '메이풀우드의 마지막 집' '도라지꽃-연작소설 호수공원4' '세월의 江물소리'
#  '불타는 신록' '언덕에 부는 바람' '오월제' '바람으로 오는 사람' '사랑을 아느냐고 내게 물으면']
# ['시계가 걸렸던 자리' '저녁이 아름다운 집' '발명의 대가' '늪을 건너는 법' '비밀의 문']
# ['표준국어대사전']
# ['페미니즘: 차이와 사이']
# ['2018 한류백서' '2019 한류백서']
# ['한국-사우디 협력 50년사: 협력과 상생의 발자취']
# ['한국현대여류시인연구-(1)노천명론']
# ['아시아의 드라마']
# ['채만식 중·장편 소설 연구']
# ['하층계급 인물의 생성과 사회 구조망 －조선작의 ≪영자의 전성시대≫를 중심으로－'
#  '하층계급 인물의 생성과 사회 구조망  －조선작의 ≪영자의 전성시대≫를 중심으로－']
# ['기억의 정치']
# ['남성성과 젠더' '지금 여기의 페미니즘 × 민주주의' '피해와 가해의 페미니즘' '영 페미니스트, 넷페미의 새로운 도전']
# ['전후 희곡의 명랑과 우울']
# ['「가족의 기원」에 관한 역사소설적 탐구, in 그해 겨울은 따뜻했네' '한국 전쟁과 주체성의 서사 연구' '박완서 문학 길찾기'
#  '박완서-자기상실의 ‘근대사’와 여성들의 자기 찾기' '가족 이야기는 어떻게 만들어지는가'
#  '박완서: 자기상실의 ‘근대사’와 여성들의 자기' '박완서: 자기상실의 ‘근대사’와 여성들의 자기 찾기'
#  '가족이야기는 어떻게 만들어지는가' '박완서' '박완서, 그녀가 남긴 것'
#  '비교 역사적 연구를 통해 본 정동 연구의 사회정치적 의제： ‘여자 떼’ 공포와 다스려질 수 없는 자들의 힘'
#  '증강 현실적 신체를 기반으로 한 대안기념 정치 구상: 애도 주체와 현실의 증강, 그리고 ‘완서학’의 원천'
#  '전쟁 상태적 신체와 슬픔의 공동체 : 냉전 체제의 사회 병리적 현상에 대한 담론과 정념 공동체의 위상'
#  '우리 시대의 소설가 박완서를 찾아서' '박완서 : 자기상실의 ‘근대사’와 여성들의 자기찾기'
#  '박완서 문학 연구 – 억척 모성의 이중성과 딸의 세계의 의미를 중심으로' '여성 수난사 이야기, 민족국가 만들기와 여성성의 동원'
#  '연대(solidarity)와 전유(appropriation)의 갈등적 역학－ 포스트 콜로니얼리즘, 탈민족주의, 젠더 이론의 관계를 중심으로'
#  '무한히 정치적인 외로움' '그해 겨울은 따뜻했네' '박완서-자기상실의 근대사와 여성들의 자아 찾기' '페미니즘 문학비평'
#  '테마기획 새로운 여성문학상의 가능성- 패밀리 플롯으로 서사화되는 자기정체성과 역사 그리고 소설'
#  '음란과 혁명－풍기문란의 계보와 정념의 정치학' '박완서 문학 길찾기\uf000' '박완서 그녀가 남긴 것'
#  '음란과 혁명:풍기문란의 계보와 정념의 정치학' '박완서-자기상실의 ‘근대사’와 여성들의 자기찾기'
#  '나는 당신의 속내 이야기를 들어주는 사람' '박완서: 자기상실의 ‘근대사’와 여성들의 자기찾기'
#  '박완서 문학 연구-억척모성의 이중성과 딸의 세계의 의미를 중심으로'
#  '박완서 문학 연구-억척 모성의 이중성과 딸의 세계의 의미를 중심으로' '박완서 문학 연구'
#  '추모 고 박완서 선생-작가를 기억하는 미래형 방식을 위하여: 박완서, 그녀가 남긴 것'
#  '수난사 이야기로 다시 만들어진 민족 이야기. in: 문학 속의 파시즘'
#  '박완서 문학 연구-억척모성의 이중성과 딸의 세계의 의미를 중심으로-'
#  '엄마의 이야기는 그녀에게 어떤 의미였을까-기억과 해석을 통한 역사적 경험의 재구성' '‘가족의 기원’에 관한 역사소설적 탐구'
#  '식민지 이후를 사유하다' '11,389-410쪽' '소년범, 작가, 음란범 : 죄 많은 아이와 냉전 키드의 탄생과 종말'
#  '박완서 문학 길찾기: 박완서 문학 30년 기념비평집' '여성 살해 위에 세워진 문학/비평과 문화산업'
#  '자기상실의 ‘근대사’와 여성들의 자기 찾기' '여성 수난사 이야기의 역사적 층위'
#  '박완서 문학 연구-억척 모성의 이중성과 딸의 세계의 의미를 중심으로-' '팽목항에서 불어오는 바람' '약속과 예측'
#  '신냉전\u3000질서의\u3000도래와\u3000혐오발화／증오\u3000정치\u3000비교역사\u3000연구'
#  '‘모성의 집’에 대한 공포' '여자떼 공포, 젠더 어펙트: 부대낌과 상호작용의 정치']
# ['여성결혼이민자 문화 리터러시 습득의 평생교육적 함의' '차이와 차별 : 한국 근현대 사치 소비의 문화사']
# ['절망 속에서 희망을 꽃피우는 작가']
# ['1960년대 ‘중산’의 사회ㆍ문화적 형성과 문학' '1960년을 묻다' '그 천편일률로서의 새로움' '1970 박정희 모더니즘'
#  '연애의 시대 : 1920년대 초반의 문화와 유행' '박정희 모더니즘' '실존, 자유, 프래그마티즘, 아프레걸 사상계를 읽다'
#  '아프레걸 사상계를 읽다'
#  '실존, 자유부인, 프래그머티즘-1950년대의 두 가지 ‘자유’개념과 문화. in: 아프레걸,《사상계》를 읽다'
#  '실존, 자유부인, 프래그머티즘 ― 1950년대의 두 가지 ‘자유’ 개념과 문화'
#  '4월의 문학혁명, 근대화론과의 대결 -이청준과 방영웅, 『산문시대』에서『창작과비평』까지'
#  '냉전의 포크너, 냉전 너머의 포크너: 1950년대 한국에서의 수용 양상과 문학적 가능성'
#  '1960년을 묻다 : 박정희 시대의 문화정치와 지성']
# ['아프레걸, 사상계를 읽다']
# ['포천 요양병원서 불… 치매환자, 침대에 손 묶인 채 숨져']
# ['한국문학의 영어권에 있어서의 수용 및 연구 현황 - 미국을 중심으로']
# ['기억, 정체성 그리고 문화적 기억으로서의 시대소설']
# ['탈민족 주의와 트라우마 －유미리의 에세이를 중심으로－' '비판  그리고 ‘성찰’의 현상학'
#  '근대문학과의 대화를 통한 망명과 말년의 양식\xad―최인훈의『화두』에 대해']
# ['시치료의 이론과 실제']
# ['탈북 작가의 장편 소설 연구']
# ['노년과 죽음의 문화 - 노년과 자유 -']
# ['여성 문화 사회']
# ['분단희곡의 담론 특성에 관한 연구']
# ['아직 멀었다는 말' '안녕 주정뱅이']
# ['한국현대문학대사전' '염상섭 전집 별권' '한국현대문학사2' '한국현대작가연구\uf000' '박완서 문학앨범' '박완서론'
#  '한국현대문학사 1, 2' '한국현대문학사 2' '박완서論' '한국현대문학사' '한승원의 삶과 문학' '말과 삶과 자유'
#  '박완서 문학 앨범' '북한의 문학' '박완서 소설과 도덕적 리얼리즘 , In 박완서 一周忌展엄마의 말뚝'
#  '1945～2000 한국현대문학사 2' '한국 계급문학 운동사' '동시대인들의 꿈 혹은 고통' '16회 이상문학상 수상작품집'
#  '정지용 전집 2 산문' '한국현대문학작품연표 1' '한국현대문학작품연표 2' '한국계급문학운동연구' '한국현대문학사 2권'
#  '한국 현대문학사2']
# ['박완서 소설의 젠더지리학적 고찰'
#  '박완서의 『미망』에 나타난 (탈)근대공간의 건축술 : 젠더지리학의 관점에서 바라본 개성(開城)의 탄생']
# ['여성의 인간화']
# ['가사문학대계' '규방가사연구']
# ['자크 라깡 욕망이론']
# ['‘괴물-아이’의 엄마 되기:『다섯째 아이』와 모성서사의 비판적 잠재성']
# ['이청준 깊이 읽기' '오정희 깊이 읽기' '김원일 깊이 읽기' '원체험과 변형 의식,오정희론(오정희 깊이 읽기)'
#  '권력형 글쓰기에 대하여']
# ['주술 개념 형성에 관한 연구: 근대 이후 서구를 중심으로' '주술 개념 형성에 관한 연구']
# ['가족과 근대성']
# ['녹슬은 해방구']
# ['살아 있으므로, 미쳐가는 모든 것들' '가족주의에 나타난 식민과 탈식민의 두 징후']
# ['박완서 소설 연구 : 성장기 소설을 중심으로']
# ['고독사 예방을 위한 노인돌봄서비스 강화방안' '치매와 가족']
# ['2002 이상문학상 수상작품집' '4월의 물고기']
# ['?언어를 바깥을 사유하는 새로운 서사－김훈 『강산무진』, 한유주 『달로』?']
# ['겨울선인장']
# ['한국의 세기 뛰어넘기-산업화 민주화 시민사회' '한국의 세기 뛰어넘기']
# ['자크 라캉, 욕망이론' '박완서문학30주년 기념비평집' '라캉, 장자, 태극기' '욕망 이론' '짐승의 시간과 전이적 글쓰기'
#  '소설을 어떻게 볼 것인가' '최인훈의 작품 세계: 전쟁의 어질머리를 풀어가는 문학' '우리시대의 욕망읽기'
#  '특집좌담 : 포스트모더니즘의 여러 쟁점들' '영화와 소설 속의 욕망이론']
# ['박완서 소설의 성장소설적 양상 : 「그 많던 싱아는 누가 다 먹었을까」와 「그 산이 정말 거기에 있었을까」를 중심으로']
# ['전쟁과 가족' '귀신 간첩 할머니-근대에 맞서는 근대' '귀신, 간첩, 할머니-근대에 맞서는 근대' '학살 그 이후'
#  '베트남전의 유령들' '학살, 그 이후' '또 하나의 냉전' '베트남 전쟁의 유령들']
# ['고령자의 사회적 고립 극복을 위한 윤리적 성찰-폴 리쾨르의 견해를 중심으로' '고령화시대 노인 고독사 문제에 대한 윤리적 반성']
# ['문학지리학 연구의 정체성과 연구방법론 고찰']
# ['반공주의 회로판 읽기: 한국 반공주의의 의미체계와 정치사회적 기능']
# ['시론']
# ['고학년 아동을 독자로 하는 서사물은 ‘아동소설’이다' '유은실 아동소설 연구-독자 문제를 중심으로-']
# ["재일조선인'과 한국사회: 한국사회는 재일조선인을 어떻게 '표상'해왔는가"]
# ['박화성 여행소설의 은유와 환유']
# ['문화간 적응교육의 개념과 실제']
# ['무정의 수용미학적 연구']
# ['문화연구입문']
# ['비평론']
# ['발터벤야민과 메트로폴리스' '발터 벤야민과 메트로 폴리스']
# ['정동이론']
# ['정체성 정치']
# ['거울 밖으로 나온 기형도']
# ['스펙타클의 사회']
# ['명랑백일장']
# ['입속의 검은 입' '짧은 여행의 기록' '사랑을 잃고 나는 쓰네' '기형도 전집' '숲으로 된 푸른 성벽'
#  '기형도, 삶의 공간과 추억에 대한 경멸' '묵시(默視)와 묵시(默示) : 상징적 죽음의 형식']
# ['여공 1970, 그녀들의 反역사']
# ['여인들과 진화하는 적들']
# ['말하는 입과 먹는 입']
# ['입속의 검은 잎']
# ['저만치 혼자서']
# ['살의의 섬뜩한 아름다움, 『불의 강』']
# ['제28회 이상문학상 작품집']
# ['2021 제12회 젊은작가상 수상작품집']
# ['근대 이후 이순신 인물 서사 변화 과정의 의미 연구']
# ['‘한류’도 문명사적 의미가 있을까?']
# ['염상섭 단편소설의 전개과정' '말․삶․글' '쓸쓸한 그리고 인간적인-노년소설의 가능성에 대하여' '소설의 기교'
#  '여성 삶의 복원에 대하여, In 박완서 문학 길찾기' '여성성의 탐구와 그 소설화-오정희론' '페미니즘 문학비평' '문학의 편견'
#  '현대소설' '여성 삶의 복원에 대하여: 엄마의 말뚝 1-3 연작론, In 박완서 문학의 길찾기'
#  '엽편소설의 전통과 새로운 가능성' '여성 경험의 소설화와 삽화 형식' '쓸쓸한 그리고 인간적인; 노년소설의 가능성에 대하여'
#  '여성 성장소설의 제의적 국면, in: 페미니즘과 문학비평' '여성 삶의 복원에 대하여-<엄마의 말뚝1․2․3>연작론'
#  '여성적 광기와 그 심리적 원천' '현대소설의 전개와 환상성' '쓸쓸한 그리고 인간적인 - 노년소설의 가능성에 대하여'
#  '여성성의 탐구와 그 소설화(문학의 편견)' '쓸쓸한 그리고 인간적인―노년소설의 가능성에 대하여' '여성 성장소설의 제의적 국면'
#  '엽편(葉篇)소설의 전통과 새로운 가능성' '여성경험의 소설화와 삽화형식- <저문 날의 삽화>론' '박완서 문학 길 찾기'
#  '강경애 장편소설 재론']
# ['‘갈등’의 함의와 교육적 활용']
# ['근대 여성문학의 탄생과 미디어의 교통' '여성해방의 시각에서 본 박완서의 작품세계' '박완서 문학을 보는 시각'
#  '노년여성의 귀환과 탈가부장의 징후들' '여성 (2)'
#  '주변부 여성 서사에 관한 고찰-이해조의 『강명화전』과 조선작의 『영자의 전성시대』를 중심으로' '오늘의 문예비평'
#  '개성 1931-서울 1991' '박완서문학을 보는 시각'
#  '개성 1931—서울 1991 : 복원되지 못한 것들을 위한 부단한 변 주'
#  '여성해방의 시각에서 본 박완서의 작품세계, In 여성 2' '여성 2' '87년체제와 한국 여성문학의 변화'
#  '통속의 정치학- 1960년대 후반 김승옥 ‘주간지 소설’ 재독(再讀) -' '｢여성해방의 시각에서 본 박완서의 작품세계']
# ['1920년대 「신문」을 통해본 목포 사람들의 도시생활']
# ['제40회 이상문학상 수상작품집' '제40회 이상문학상 작품집: 천국의 문 외' '혁명기념일,In 신에게는 손자가 없다'
#  '소년은 늙지 않는다']
# ['박완서 논쟁과 여성문학이 나아갈 길' '리얼리즘 문학의 공간성과 역사성-김정한의 1960년대 소설을 중심으로']
# ['한국의 근대와 근대성' '1950년대의 일상생활과 근대성,전통. in: 한국의 근대와 근대성']
# ['근대화']
# ['한국사회의 ‘가족주의’ 담론과 ‘유교 가족주의’에 대한 성찰']
# ['황순원의 장편소설 연구 - 소설에 나타난 죄의식과 구원의 문제를 중심으로']
# ['인문학적 노년학의 관점에서 본 『나빌레라』 －한국 만화에 재현된 새로운 노년관－']
# ['황순원 소설의 공간 연구']
# ['발달심리학' '한국속담 프랑스어 번역에 관한 고찰' '문화차이의 번역에 관한 고찰' '「검은 나무」의 신화성 분석'
#  '오정희 소설에 나타난 모성성 연구' '오정희 소설에 나타난 모성성 연구–「중국인 거리」,「번제」를 중심으로']
# ['베버, 뒤르케임, 슈츠, 그리고 2016~2017년: 촛불혁명을 보는 사회학의 시각']
# ['한국 현대사 이해']
# ['한국 근현대예술가 구술채록연구 시리즈: 52']
# ['기묘한 우정 In 월간문학\uf000']
# ['사회공포증']
# ['전시한국문학선']
# ['역사적 상흔의 증언' '호소력의 문제']
# ['이산가족, ‘반공전사’도 ‘빨갱이’도 아닌…' '잃어버린 또 하나의 역사(한국전쟁시기 강원도 양양군 미군정 통치와 반성)'
#  '한국전쟁기 한국군에 의한 성폭력의 유형과 함의' '이산가족, 반공전사도 빨갱이도 아닌' '아래로부터의 반공 이데올로기 허물기'
#  '구술사 연구: 방법과 실천' '전쟁의 기억 냉전의 구술' '이산가족, ‘반공전사’도 ‘빨갱이’도 아닌']
# ['한국 근현대예술가 구술채록연구 시리즈 34: 김규동' '임진강 흘러 하나 되리']
# ['88서울올림픽 이후 중소기업의 해외투자전망']
# ['박완서 『도시의 흉년』에 나타난 ‘우리집’의 공간성과 주체 모색의 정치성']
# ['한국노인복지의 이해' '알기 쉬운 치매의 이해']
# ['김원일 소설의 성장주체 연구']
# ['기다림']
# ['디지털시대 인문학 성과의 산업화 방안 연구']
# ['여류문인']
# ['〈길소뜸〉: 보이는 것과 보이지 않는 것']
# ['삼국사기와 삼국유사: 역사와 문학의 만남']
# ['박완서 소설연구-현실반영을 중심으로 한 작가의식 고찰']
# ['무정 122회를 독하다가, 매일신보,']
# ['삶, 그 흔들림의 형이상학']
# ['모나코']
# ['마종기 시의 공간 의식의 변화에 대한 고찰']
# ['아흔 개의 봄']
# ['｢金廷漢 초기소설과 그의 전향에 대한 고찰\xad작중인물의 현실대응의 변모를 중심으로｣ 우리어문학연구 제3집']
# ['박완서 장편소설의 서사전략 연구' '야멸친 베스트셀러 독서법-신경숙, 박범신 장편소설 다시 읽기']
# ['재브라질 한인문학의 형성과 성향']
# ['고정희 ‘굿시’에 나타난 기호적 코라의 특성 - 『저 무덤 위에 푸른 잔디』를 대상으로 -']
# ['캐나다 한인문학비평의 전개 양상 연구 —‘이민문학론’의 생성과 정립 과정을 중심으로—']
# ['‘전태일 평전’ 25년만에 개정판 나와']
# ['민중신학자 안병무 평전' '명동부루스']
# ['아름다운 사람들']
# ['데탕트 이후 영화의 한국전쟁 재현 양상에 대한 연구- 더글라스 맥아더 혹은 인천상륙작전 관련남한, 북한, 미국 영화를 중심으로']
# ['전통한옥의 현대적 사용에 따른 변형 실태와 보전 방안에 관한 연구 : 서울시 전통한옥의 내부공간을 중심으로']
# ['알레고리와 역사']
# ['영화 <서부전선>에 재현된 헤테로토피아: 그 생성과 소멸의 구조']
# ['한국전쟁 전후 부산 제조업의 입지 및 업종변화']
# ['제도의 해체와 확산, 그리고 문학의 정치 ―1980년대 무크지 운동 재고']
# ['“당혹스럽다” 직원들 반응... ‘올해의 최우수 신입사원’ 누구길래']
# ['문학교육원론']
# ['원본 없는 판타지']
# ['돈의 철학' '현대의 현상학-게오르그 짐멜 연구' '게오르그 짐멜의 모더니티 풍경 11가지' '(짐멜의)모더니티 읽기'
#  '에리식톤 콤플렉스, 한국 자본주의의 정신']
# ['아메리카나이제이션-해방 이후 한국에서의 미국화' '세탁기의 배신']
# ['차이의 정치와 정의']
# ['상호텍스트성과 텍스트 이해 교육']
# ['장애학의 도전']
# ['일제말기 대구24부대 학병 탈출의거' '일제 말기 필리핀·버마지역 한인 병사의 강제동원과 귀환']
# ['한국 영화 속 아버지 담론 연구 : 열등감 콤플렉스의 극복']
# ['한국어-영어 감정 은유의 개념화 과정 및 한영 번역']
# ['멜랑콜리아 : 서양문화의 근원적 파토스' '탈출에 관해서']
# ['사회 적응의 노인심리학']
# ['한 연구사에 대한 추억' '약속, In 전환' '그이듬해']
# ['밀다원 시대' '실존무' '흥남철수' '심사평-등장인물의 성격묘사에 심혈 기울여' '소설천후기' '여류작가의 회고와 전망']
# ['생태주의의 스펙트럼과 시학']
# ['위선자의 문학, in 뿌르조아의 인간상']
# ['신소설에 등장하는 죽음의 양상 ―소문과 꿈을 중심으로'
#  '잡지의 시대, 매체의 시대, 문학의 시대－1980년대 문학과 관련된 기존 연구 검토를 대신하여' '존재를 위하여: 한강과 윤대녕'
#  '낭만적 사랑의 의미론' '숨쉬기의 무의식에 관하여, In 명랑'
#  '잡지의 시대, 매체의 시대, 문학의 시대–1980년대 문학과 관련된 기존 연구 검토를 대신하여']
# ['서울의 지형적 배경과 도시화 양상']
# ['수도의 재구성과 수도권의 탄생 : 1960년대 초반 서울특별시의 변화를 중심으로']
# ['문자로서의 도시, 도시시학의 가능성 - 도시인문학의 이론적 기초 -']
# ['프랑스 ‘디지털 인문학’의 인문학 맥락과 동향' '신문소설의 재조명' '김석희 소설 「땅울림」에 나타난 독립적 자치주의']
# ["Bare Hills -a doctor's memoir-, In  Korean Short Stories"
#  "The Red Hills: A Doctor's Diary, In Modern Korean Short Stories" '춘원연구'
#  '춘원연구, in 동인전집 8권']
# ['1960년대의 사회운동\uf000']
# ['전쟁과 사회' '전쟁정치-한국 정치의 메카니즘과 국가폭력' '근대의 그늘' '서울시민과 한국전쟁'
#  '전쟁과 사회 우리에게 한국전쟁은 무엇이었나' '전쟁과 사회 : 우리에게 한국전쟁은 무엇이었나' '이것은 기억과의 전쟁이다'
#  '유교와 한국의 가족주의-가족주의는 유교적 가치의 산물인가?-' '전쟁정치–한국정치의 메카니즘과 국가폭력'
#  '한국인의 에너지, 가족주의' '한국인의 에너지, 가족주의 : 개인의 보호막과 지위상승의 발판인 가족'
#  '시험능력주의-한국형 능력주의는 어떻게 불평등을 강화하는가' "'간첩 만들기'의 전쟁정치: 지배질서로서 유신체제"]
# ['변화하는 노인의 삶과 노인복지']
# ['‘여성’ 그 왜곡된 기호에 대한 시적 저항-고정희 시집 여성해방출사표의 세계']
# ['빨갱이의 탄생' "'빨갱이'의 탄생" '‘빨갱이’의 탄생']
# ['애인' '한국문학전집 24']
# ['우아한 거짓말']
# ['흥미와 진실을 론하고 싶어－중편소설 ‘교정의 륜리’를 놓고(평론)' '작품의 심리묘사']
# ['문화냉전-미군의 공보선전과 주한미공보원 영화']
# ['메갈리안들의 ‘여성’ 범주 기획과 연대: “중요한 건 ‘누가’ 아닌 우리의 ‘계획’이다.”']
# ['압록강']
# ['문학의 교육, 문학을 통한교육' '80년간의 개인사, 가족사, 사회사-박완서론']
# ['내 사촌 별정 우체국장,In 내 사촌 별정 우체국장']
# ['작가 박완서와 문학교육 -2011 개정 국어 교과서를 중심으로-' '<마당을 나온 암탉>의 서사 분석과 다문화 교육'
#  '작가 연구와 문학 교육'
#  '문학공간으로서의 블로그와 인터넷 시대의 소설 읽기-박범신의 <촐라체>와 황석영의 <개밥바라기별>을 중심으로-']
# ['전쟁명명의 정치학: ＂아시아ㆍ태평양전쟁＂과 ＂6∙25전쟁＂']
# ['안병무–시대와 민중의 증언자']
# ['‘좋은 죽음’과 유학의 죽음관' '모옌 문학 한국어 역본에 나타난 문화정보의 유실과 오독'
#  '여신은 젠더를 넘어설 수 있는가? -페미니스트 영성운동을 중심으로-']
# ['뉴욕뜨기']
# ['부숭이의 땅힘' '슬픔을 힘으로 바꾸는 작가정신의 연금술; 양귀자의 변모와 90년대 리얼리즘 소설에의 기대'
#  '대학교수는 무엇으로 사는가?' '희망의 은유를 찾아서, 주례사 비평을 넘어서'
#  '새로운 여성문학 향한 디딤돌—김영혜씨 여성문제소설 비평을 보고']
# ['여성과 민주화운동']
# ['고전문학 上']
# ['김원일 소설에 나타난 ‘문학적 증언’의 미학과 윤리 연구'
#  '‘학살은 재현될 수 있는가’라는 질문을 역사화하기 : 1980년대 후반 소설의 정치적 무의식과 ‘거창사건’']
# ['일본군‘위안부’ 문제와 부인(denial)의 정치학: ‘『제국의 위안부』 사태’ 다시 읽기']
# ['사회사적 관점에서 본 우리나라 도시빈민의 형성배경과 주거문화-한국전쟁 이후 집단이주민촌부터 외환위기 이후 신빈곤층 주거까지-']
# ['박완서 에세이 연구']
# ['1970년대 중동건설노동자 담론과 글쓰기 연구-『밀물』의 수기를 중심으로'
#  '1970년대 중동건설노동자 담론과 글쓰기 연구－"밀물"의 수기를 중심으로']
# ['일기를 통해 본 전통과 근대, 식민지와 국가']
# ['해방기 소설에 나타난 전향 모티프와 그 논리' '오늘도 무사히']
# ['규방가사에 나타난 조선 시대의 부부 관계와 아내의 태도']
# ['손창섭 소설에 나타난 사랑의 양상과 젠더 표상 - 『부부』와 『인간교실』을 중심으로'
#  '『도시의 흉년』에 나타난 여성상과 중산층의 형성' '『서 있는 여자』에 나타난 계약으로서의 결혼과 ‘여성적 글쓰기’']
# ['고정희 시의 종교적 영성과 ‘어머니 하느님’'
#  'A Study on 1980’s the Mook movement and the Change of Literary Field'
#  '1980년대 무크지 운동과 문학장의 변화']
# ['비평문학']
# ['희곡 ｢칠산리｣의 표현 기법 연구']
# ['낙태 담론과 페미니즘 욕망의 문학적 형상화 - 아이힝어의 『거울이야기』와 박완서의 『그 가을의 사흘동안』을 중심으로']
# ['주한미군 기지 정치(Base Politics) 연구에 대한 검토']
# ['‘시민－소시민 논쟁’의 정치학'
#  '모옌(莫言) 문학의 생명의식과 모성, 그리고 비판성― 《개구리(蝸)》와 《풍유비둔(豊乳肥臀)》을 중심으로'
#  '만주, 혹은 자치에 대한 상상력과 안수길 문학' '중국은 왜 한류를 수용하나']
# ['「한국 무가」(韓國 巫歌)의 영역(英譯) —가독성을 위한 번역전략 및 사례를 중심으로—']
# ['<명저읽기>에 대한 성찰과 지향점 -조선대학교 사례를 중심으로']
# ['1950~1960년대 여성의 소비문화와 명동(明洞)의 장소성에 관한 연구  - 양장점과 미장원을 중심으로 -'
#  '명동 아가씨 : 근현대 여성 공간의 탄생']
# ['자아의 표출과 사적 역사의 문자화 - 「세기아의 고백」을 중심으로']
# ['고령화사회의 사회경제적 문제와 정책대응방안 –OECD 국가의 경험을 중심으로']
# ['소설에서의 치매 서사의 수용' '박완서 소설 속 돌봄 인식 방식 연구'
#  '교양소설에 나타난 음식과 그로테스크 - 오수연의『부엌』을 중심으로 -' '박완서의 장편소설에 나타난 음식의 문학적 재현과 의미'
#  '공선옥 소설에 나타난 생태학적 상상력 고찰'
#  '한국 노년기 작가들의 노년소설 연구 - 최일남, 박완서, 이청준, 홍상화, 김원일의 작품을 중심으로 -'
#  '치매 소설에 투영된 치매자의 주체적인 삶'
#  '대학생의 정체성 혼미와 우울과의 관계에서 긍정적 자아인지와 부정적 자아인지의 매개 효과' '박완서 소설에 나타난 감정 연구'
#  '박완서의 성장 소설과 여성 주체의 성장' '김원일의 성장소설과 ‘삶의 수수께끼’ 풀기' '고정희 시에 나타난 패러디 연구'
#  '최인훈의 환상성, 현실 인식과 문학적 상상력의 결합' '현대소설에 나타난 변신 모티프와 환상'
#  '신경숙 단편소설에 나타난 생태적 사유와 글쓰기' '박완서 소설의 치유 공간 연구' '넘치는 ‘욕망’, 붕괴되는 ‘개인’'
#  '박완서의 단편소설에 나타난 음식의 문학적 재현과 의미' '小說敎育의 한 可能性－生態小說을 중심으로－'
#  "박완서 소설의 애도 불가능성 연구 - '나목'의 모녀관계를 중심으로 -" '박완서 소설의 감정구조 연구'
#  '이어령 에세이에서의 ‘유럽’이란 심상지리'
#  "음식의 문학적 재현과 주체화의 방식 - 한강과 오수연의 소설에 나타난 '음식'을 중심으로 -"
#  '낙태 서사에 내재된 행복의 폭력성 -박완서의 「꿈꾸는 인큐베이터」를 중심으로-']
# ['안수길의 북간도연구']
# ['박완서 소설 연구 : 체험과 목격을 통한 글쓰기를 중심으로']
# ['서울 동굴 가이드' '여덟번째 방' '아무도 펼쳐보지 않는 책']
# ['‘몸의 공간성’에 대한 고찰 -오정희 소설〈옛우물〉을 중심으로' '민주주의 증언 인문학'
#  '여성교양소설의 불/가능성－‘한국－루이제 린저’의 경우(1)' '움직이는 별자리' '‘수치(shame)’와 근대'
#  '‘기억-정동’ 전쟁의 시대와 문학적 항쟁－한강의 『소년이 온다』(2014)가 놓인 자리－']
# ['『82년생 김지영』(2016)과 겹쳐 읽은 『무소의 뿔처럼 혼자서 가라』(1993) - 페미니즘과 소설의 전략'
#  '월북문인 해금의 이면—‘불화’의 소멸 그 이후']
# ['1970년대 박완서 소설의 ‘남성성’ 연구' '아주 오래된 농담' "2010년대 여성소설에 나타난 '자기 돌봄'의 윤리"
#  '소설, 노년을 말하다' '한국 여성 소설과 페미니즘' '박완서 소설의 근대 번역 양상  ― ｢엄마의 말뚝 1｣을 중심으로'
#  '한국여성소설과 페미니즘' '박완서문학 길찾기-박완서 문학 30년 기념비평집'
#  '오정희 소설의 우울증적 여성언어 - 「저녁의 게임」을 중심으로 -' '이 노년을 보라' '수상한 소설들' '여성문학을 넘어서'
#  '여성소설에 나타난 환상성 연구' '한국어문학 여성주제어 사전 2. 몸' '번역 그리고 반역, In 『아주 오래된 농담』작품 해설'
#  '웬 아임 올드, in: 소설, 노인을 말하다' "웬 아임 올드 (When I'm old) in: 소설, 노년을 말하다"
#  '인어공주와 아마조네스 그 사이' '이브의 몸, 부재의 변증법 -한국 여성소설에 나타난 여성의 몸'
#  '이창래의 『항복자』에 나타난 생존의 의미' '박완서 문학 길찾기' '젠더 프리즘'
#  '오정희 소설의 모성성에 대한 재해석 -「번제」를 중심으로'
#  '가족이데올로기의 종언― 1990년대 이후 소설에 나타난 탈가족주의 ―'
#  '21세기 재난소설의 ‘비장소(Non-Place)’와 경계 사유 - 편혜영의 재난소설 3부작을 중심으로 -']
# ['다문화 문식성 신장을 위한 문학교육의 방향 연구' '박완서 소설 연구 : 2000년대 노년·여성·가족문제 중심으로'
#  '성장소설의 교수·학습 방법 연구 : 박완서「자전거 도둑」을 중심으로']
# ['소설『미망』속 19세기말 개성의 음식문화']
# ['박완서 소설을 통해 본 가족 해체와 그 대안']
# ['郁達夫의 《沈淪》국내 번역본의 문화소번역 비교연구']
# ['새로운 이야기 방식과 독자의 자리-유은실 동화 꼼꼼히 읽기-']
# ['무능현실 전능예술의 역설, 오타쿠 문화와 무라카미 다카시로 본 일본']
# ['의료보험 행정의 역사적 변천 과정 소고']
# ['오정희 소설에 나타난 생성과 소멸의 순환적 인식'
#  '누스바움의 감정철학으로 바라본 오정희의 「유년의 뜰」 - 혐오, 수치심, 연민을 중심으로 -']
# ['1970년대 여성문학의 정치성에 대한 연구 시론' '젠더 정치학' '메를로-퐁티의 살 존재론과 몸의 반성']
# ['K-Pop 번역 양상 연구: 번역 주체와 전략을 중심으로'
#  '1990년대 페미니스트 페다고지와 문학 비평의 접점: 조한혜정의 「글 읽기와 삶 읽기」를 읽고'
#  '‘가사 노동’ 의제화 과정 속 서사의 의의']
# ['강남 개발과 올림픽 효과 ― 1970~80년대 잠실 올림픽타운 조성사업을 중심으로' '도시는 역사다'
#  '제국의 스펙터클 효과와 식민지 대중의 도시경험― 1930년대 서울의 백화점과 소비문화']
# ['이야기치료와 상담']
# ['이주민 시민권으로서의 다문화주의 시민권의 한계와 대안: 벤하비브의 시민권 정치를 중심으로']
# ['한국 여성작가 소설에 나타난 일상성 연구: 박완서·오정희·양귀자를 중심으로'
#  '환멸의 세계와 탐미적 서사-박범신론, In 한국문예창작 8' '지식인 소설의 새로운 양상'
#  '우리 소설에 나타난 다방의 심리 지리학' '불모의 현실과 여성적 화해의 세계 - 윤흥길론']
# ['현대 소설의 이론' '한국현대소설의 공간의식']
# ['이청준' '현대한국문학의 이론' '노년소설·심화의 끝의 소설-노년과 중년기 작가의 변모와 기대'
#  '대립적 세계관과 미학, 난장이가 쏘아올린 작은 공' '1960년대와 그 문학, 21세기를 받아들이기 위하여' '친절한 복희씨'
#  '세계에의 비극적 비전-오정희의 소설들' '글치기 시대의 글의 모습' '상황과 상상력' '한국문학'
#  '기억의 타작-도저한 작가 정신을 위하여' '문화와 반문화' '일요작가의 꽁트-아마츄어소설은 가능한가'
#  '거짓된 세상을 아프게 껴안다, 모든 것에 따뜻함이 숨어있다' '노년 소설 침묵 끝의 소설 - 노년과 중년기 작가의 변모와 기대'
#  '남북조 시대 작가’의 의식의 자서전' '수난기의 결벽주의자의 초상' '지성과 문학' '기억의 타작 - 도저한 작가 정신을 위하여'
#  '문학과사회 1(창간호)']
# ['『창작과비평』, 『문학과지성』을 말한다 - 김병익, 염무웅 초청 대담 -']
# ['대검자']
# ['시의 건축공간 수용 - 현실 수용과 역사 수용을 중심으로']
# ['海東歌謠(朴氏本) 附 永言選']
# ['한국 현대 성장소설의 구조와 의미망']
# ['황순원 엽편소설 연구' '황순원 연구' '『또 하나의 문화』의 여성시에 나타난 ‘차이’라는 여성 연대의 조건과 가능성']
# ['미국 제2물결 페미니즘에 대한 역사적 평가들에 대한 소고']
# ['한국 현대 노년소설 연구' '노년소설에 나타난 죽음인식과 대응'
#  '노년소설에 나타난 노년의 성 - 김원일, 박완서, 한승원 작품을 중심으로 -']
# ['개발연대 중동건설현장 취업자의 경제와 정치 — 돈과 노동, 조국과 가정' '박정희 시대의 새마을운동-근대화, 전통, 주체']
# ['1950년대 소설에 나타난 반미의 양상과 젠더' '‘지식인 빨치산’의 계보와 『지리산』' '페미니즘 미학과 보편성의 문제'
#  '신식민지 시기 반미소설의 계보와 서사원리로서의 젠더  -  해방 직후~1970년대를 중심으로'
#  '‘여성-노동소설’의 일 계보 - 김인숙의 경우' '방법으로서의 젠더'
#  "1950년대 여성소설의 전쟁인식과'기억의 정치학'-강신재의 초기단편을 중심으로"
#  '『시장과 전장』에 나타난 사랑과 이념의 두 구원' '페미니즘 시학과 리얼리티의 문제'
#  '‘말걸기’와 어머니？딸의 플롯？박완서의 ？엄마의 말뚝？ 연작을 중심으로？' '페미니즘미학과 보편성의 문제'
#  '소녀의 탄생과 반공주의 서사의 계보 -최정희의 『녹색의 문』을 중심으로-' '전후 여성교양의 재배치와 젠더정치'
#  '전향자의 역사 다시쓰기  - 최정희의 『인간사』를 중심으로'
#  '浪漫的 사랑의 系譜와 敍事原理로서의 젠더 - 1950년대 <思想界>와 <女苑>을 중심으로 -'
#  '여성적 광기와 그 심리적 원천 in: 페미니즘은 휴머니즘이다' '대중소설의 젠더정치학-「자유부인」을 중심으로'
#  "반공주의의 젠더 전유 양상과 '젠더화된 읽기': <자유부인>을 중심으로"
#  '‘이질적인 근대’체험의 비판적 서사화－하근찬론 in: 1960년대 문학연구' '1960년대 소설의 연애전유 양상과 젠더'
#  '대중소설의 젠더정치학-‘자유부인’을 중심으로' '여성 광기의 귀결, 모성혐오증' '‘지식인 빨치산’ 계보와 지리산'
#  '만보객의 계보와 젠더의 미학적 구축' "강경애의 '프로-여성적 플롯'의 특징"
#  '산업화의 최종심급과 재현의 젠더 - 1960-70년대 소설을 중심으로 -']
# ['한국전쟁 이후 1950년대 간첩 담론의 양가성']
# ['국가 기획의 가족 만들기 - 모옌 『개구리』에 나타난 가족정치의 한계와 모순']
# ['진실과 대면하는 윤리적 문제설정의 화구-분노: 자기배려윤리의 논점을 중심으로'
#  '생명관리정치에서 죽음관리정치로 -존엄사의 현행법에 대한 문제화-']
# ['싸르트르와 보봐르의 신화' '신문학초기의 계몽사상과 근대적 자아, in 한국인과 문학사상']
# ['02영이']
# ['뵈메의 새로운 미학: 분위기와 감각학']
# ['개발독재와 박정희 시대']
# ['노인의 활동성 여가참여가 사회적 역할상실감 및 삶의 질적 가치인식에 미치는 영향']
# ['노년기 신체질환이 불안의 발생에 미치는 전향적 연구']
# ['한국의 도시화에 따른 무속적 죽음관의 변화' '‘일상생활의 사회학’의 현황과 전망']
# ['정치적 상상력과 예술적 상상력' '다문화시대, 동화의 서사']
# ['곡필로 본 해방\uf000']
# ['반제ㆍ반봉건 문학선, In 반미소설선' '반미소설선' '황순원의 문학과 악']
# ['2016-2017년 촛불혁명의 역사적 위상과 목표: ‘독재의 순환고리 끊기’와 ‘한반도 양국체제 정립’']
# ['1990년대 sex라는 기호를 다루는 사람들-퇴행의 시니피앙과 그 주체들에 대하여' '박태원의 수필 세계'
#  '1990년대 sex라는 기호를 다루는 사람들－퇴행의 시니피앙과 그 주 체들에 대하여' '소설의 문체 in : 현대소설론']
# ['라깡의 재탄생' '니체, 프로이트, 맑스 이후' '이미지 없는 신체']
# ['『두려운 낯설음』에 나타난 요약의 문제점 : 프로이트의 요약을 넘어서' '프로이트의 환자들']
# ['에크리-라캉으로 이끄는 마법의 문자들' '에크리 : 라캉으로 이르는 마법의 문자들' '애도의 부재와 욕망의 좌절'
#  '아버지의 위상 - 금지와 향유의 기원' '땅울림']
# ['한국어 연구사 상']
# ['김수영 시에 나타난 ‘욕망’에 대한 연구  - 욕망의 ‘억압’과 ‘분리’를 중심으로 -']
# ['기층문화의 수평적 인식 - 환동해지역의 샤머니즘을 중심으로 -']
# ['박완서 장편 소설의 아버지 극복 과정 연구' '박완서 동화 연구' '박완서 장편소설의 아버지 극복 과정 연구']
# ['주체의 환영: 북한 문예이론에 대한 비판적 이해' '신르네상스 시기 한국영화에서의 성별/성에 대한 재현']
# ['일방적 문화편향성을 넘어 상생의 미학으로–베누티와 베르만의 이국화 번역에 대한 논의를 중심으로'
#  '치매 父 간병살인 아들, 항소심도 징역 3년' '일본 텔레비전 광고에 재현된 노인정체성 분석'
#  '데카르트에서 무의식 - 몸과 기억을 중심으로 -']
# ...
# ['여류작가 좌담회' '삼천리문학' '정적기(靜寂記)' '군국의 어머니' '황국의 아이의 어머니에게(御國の子の母に)' '半島の光'
#  '야국초(野菊抄)' '친일문학작품전집 2' '나의 문학생활자서(文學生活自敍)' '풍류 잡히는 마을'
#  '적화삼삭구인집(赤禍三朔九人集)' '사랑의 이력' '전시 한국문학선' '찬란한 대낮' '천맥' '최정희 선집'
#  '인간사 in: 정통한국문학대계']
# ['타자들 : 근대 서구 주체성 개념에 대한 정신분석학적 탐구']
# ['창세기의 족보적 이해']
# ['문제해결 능력 업그레이드']
# ['박완서 장편소설 『나목』 연구']
# ['자전적 이야기의 시점과 그 언어적 실현']
# ['국어과 교수·학습 방법' '학병(學兵)의 기억과 국가 - 1940년대 학병의 좌담회와 수기를 중심으로']
# ['아동문학평론']
# ['감응의 정치학: 코뮨주의와 혁명']
# ['타이거맘과 보그맘, 그리고 엄마']
# ['국경을 세 번 건넌 여자 최진이']
# ['창(槍)']
# ['한ㆍ일과거사 청산과 이행기 정의(transitional justice) 개념의 적용']
# ['가을향기']
# ['교주내방가사']
# ['김수영 평전']
# ['문학과 비평사']
# ['가난 탓 병역기피 가명으로 살다간 소설가, 故人돼서야…']
# ['정동']
# ['20~21세기 한반도에서 국가적 성폭력과 그 희생제의로서 여성의 몸 ―일본군위안부, 여성빨치산, 그리고 여성탈북자의 삶을 중심으로']
# ['한국현대 성장소설의 세계' '한국 현대 성장소설의 세계' '김주영 성장소설의 함의와 해석']
# ['다민족, 소수 민족, 코리안 아메리칸' '다민족 사회, 소수 민족, 코리안 아메리칸']
# ['죽은 민중의 시대 안병무를 다시 본다']
# ['사랑학']
# ['서사전략으로서 오독(誤讀)의 효과와 의의 -김영하의 『살인자의 기억법』에서 나타나는 독자의 오독(誤讀)을 중심으로']
# ['신여성들은 무엇을 꿈꾸었는가']
# ['발자크의 소설에 나타난 의상 묘사']
# ['일상의 공간과 미디어']
# ['유미리 소설에 나타난 소외 양상 연구']
# ['이산가족찾기 운동에 대한 시민참여와 방송의 공공성']
# ['개인의 탄생' '환상문학서설']
# ['자본론Ⅰ(하)']
# ['세대 문제']
# ['치매와 마주하기']
# ['자본 Ⅰ-1']
# ['이데올로기와 유토피아']
# ['자본론 상']
# ['열린사회와 그 적들 Ⅰ']
# ['거대한 전환']
# ['죄책감']
# ['비체화와 청소년용 소설. in: 아동문학 작품 읽기']
# ['다른 목소리로']
# ['남과 여, 은폐된 성적 계약' '여자들의 무질서' '페미니즘 정치사상사']
# ['남과 여, 은폐된 성적 계약']
# ['음식과 몸의 인류학']
# ['다시 태어나는 여신: 페미니스트 영성의 의미']
# ['다른 목소리로 : 심리이론과 여성의 발달' '다른 목소리로' '담대한 목소리']
# ['동맹 속의 섹스']
# ['동맹 속의 섹스']
# ['환상과 미메시스']
# ['환상과 미메시스']
# ['정동적 평등－누가 돌봄을 수행하는가' '정동적 평등-누가 돌봄을 수행하는가']
# ['이론과 서사: 역사철학에 대한 성찰']
# ['프로이드 심리학']
# ['현대 서술이론의 흐름']
# ['보부아르 여성의 탄생']
# ['성의 정치학']
# ['성(性)정치학' '성 정치학']
# ['무당, 여성, 신령들 –1970년대 한국 여성의 의례적 실천']
# ['커버링']
# ['남성성/들']
# ['신데렐라 콤플렉스']
# ['만물은 서로 돕는다']
# ['몸의 사회학']
# ['정신병, 모친살해, 그리고 창조성:멜라니 클라인']
# ['여성과 일상생활-사랑, 결혼, 그리고 페미니즘']
# ['젠더연구']
# ['일기를 통해 본 전통과근대, 식민지와 국가']
# ['바이로이드적 생명 VIROID LIFE: Perspectives on Nietzsche and the Transhuman Condition']
# ['노년에 관하여/우정에 관하여' '노년에 관하여']
# ['면역의 의미론: 자기(自己)란 무엇인가']
# ['기억문화연구'
#  '문화적 기억으로서 ‘향수 영화’가 제시하는재현 방식에 관한 연구 : 영화〈써니〉(2011),〈건축학개론〉(2012)의‘기억하기’ 방식을 중심으로']
# ['탈식민주의 페미니즘' '한국의 탈식민 페미니즘과 지식생산' '한국의 탈식민페미니즘과 지식생산' '탈식민페미니즘'
#  '‘영성’, 에코페미니즘, 사냥' '탈식민주의 페미니즘 - 하위주체로서의 여성 개념을 중심으로'
#  '포스트모던 여성해방론의 현황과 과제']
# ['회색쇼크']
# ['냉전시대 한국의 문화와 영화－자유의 경계선']
# ['문학이론입문']
# ['비평과 이데올로기－마르크스 문학이론의 한 연구']
# ['성경 파노라마']
# ['악']
# ['우리안의 과거']
# ['계몽의 변증법' '미니마 모랄리아' '미학' '[단행본]미니마 모랄리아' '베토벤. 음악의 철학-단편들과 텍스트'
#  '미니아 모랄리아-상처받은 삶에서 나온 성찰']
# ['불안한 현대사회']
# ['성과 텍스트의 정치학']
# ['생명정치란 무엇인가']
# ['생각의 오류']
# ['마음의 해부학']
# ['인종 간 입양의 사회학']
# ['봄날은 연구에 물들어']
# ['復活 上']
# ['페미니즘 교차하는 관점들']
# ['색채심리']
# ['우리는 어떻게 괴물이 되어가는가']
# ['모든것의 가장자리에서 -나이듦에 관한일곱 가지 프리즘']
# ['게오르그 루카치']
# ['상호교차성']
# ['담화의 허구']
# ['문학과 페미니즘\uf000' '문학과 페미니즘']
# ['노년의 역사']
# ['일반 언어학 강의\uf000']
# ['근대성과 혁명 in: 마르크스주의와 포스트모더니즘']
# ['냉소적 이성 비판']
# ['문학과 페미니즘']
# ['｢한국신학대학 35년의 발자취｣ 부록']
# ['야행']
# ['서사학 강의']
# ['타자로서 자기자신' '시간과 이야기 3' '시간과 이야기2' '역사와 진리']
# ['글로벌 고령화 위기인가 기회인가']
# ['장르론']
# ['근대가족의 성립과 종언']
# ['북한문학 연구의 현황과 과제, In 북한문학의 이해']
# ['전쟁과 사람들-아래로부터의 한국전쟁연구' '전쟁과 기억']
# ['저자란 무엇인가 in : 작가란 무엇인가']
# ['성의 역사1－앎의 의지' '감시와 처벌' '성의 역사 1(지식의 의지)']
# ['비평의 해부']
# ['문화/메타문화']
# ['소설형식의 기본유형']
# ['카프카의 일기']
# ['북아프리카인의 민족해방전쟁성 범죄충동 in: 대지의 저주받은 자들']
# ['루이비통이 된 푸코(위기의 미국 대학 프랑스 이론을 발명하다)']
# ['신역사주의론']
# ['포스트모더니즘론' '특별대담—맑시즘, 포스트모더니즘, 민족문화운동']
# ['황금가지 1권']
# ['정신분석하학 개요']
# ['억압, 증후 그리고 불안, 프로이트 전집12' '종교의 기원' '억압, 증후, 그리고 불안' '꼬마 한스와 도라' '늑대인간'
#  '정신분석 강의 하' '꿈의 해석' '정신분석학의 근본개념' '히스테리 연구' '쾌락원칙을 넘어서' '창조적인 작가와 몽상'
#  '정신분석강의']
# ['종교의 기원' '문명 속의 불만' '정신분석학의 근본 개념' '성욕에 관한 세 편의 에세이']
# ['성욕에 관한 세 편의 에세이']
# ['제4물결 페미니즘 : 정동적 시간성' '제4물결 페미니즘:정동적 시간성']
# ['비극의 탄생, In 니체전집 2']
# ['가족, 사유재산, 국가의 기원']
# ['인지언어학 개론']
# ['기록시스템 1800․1900' '현대 독일 미학 : 감각, 기억, 사유의 변증법']
# ['기록시스템 1800/1900 Aufschreibesysteme 1800/1900'
#  '축음기, 영화, 타자기 Grammophon, Film, Typewriter' '광학적 미디어 : 1999년 베를린 강의']
# ['페미니즘']
# ['이것이 인간인가' '가라앉은 자와 구조된 자']
# ['플라톤의 대화' '플라톤의 국가']
# ['기억의 장소 2' '기억의 장소']
# ['디지털 시대의 가상현실']
# ['구별짓기 : 문화와 취향의 사회학' '구별짓기 하(下)' '구별짓기 上' '구별짓기上' '자기 분석에 대한 초고'
#  '상징폭력과 문화재생산' '예술의 규칙' '사회학의 문제들' '재생산-교육체계 이론을 위한 요소들' '『구별짓기』 상·하'
#  '언어와 상징권력']
# ['사회학에의 초대']
# ['육체와 예술']
# ['자서전의 규약']
# ['자서전의 규약']
# ['<헌화가>의 현대적 변용 양상과 가치']
# ['옛 제자 in: 새농민' '십오야 in: 새농민' '여제자' '낙뢰, in: 신태양']
# ['망각의 강 레테-역사와 문학을 통해 본 망각의 문화사']
# ['『창조된 고전』' '창조된 고전']
# ['창조된 고전']
# ['미쳐있고 괴상하며 오만하고 똑똑한 여자들']
# ['미디어의 이해']
# ['남자다움에 관하여']
# ['1980년대 한국의 정치변동, 민주화 그리고 정치커뮤니케이션']
# ['텔레비전 영상의 미학적 특성과 문화철학적 의미에 관한 연구']
# ['소설, 노년을 말하다' '2008년 이상문학상 작품집' '옆집여자']
# ['나는 치매 의사입니다']
# ['노년의 삶과 박완서의 페미니즘']
# ['에세이 원론 , 현대에세이론']
# ['치매공포']
# ['군대와 성폭력']
# ['조그만 체험기: 박완서 단편소설 전집 2' '김원일 중⋅단편 소설 연구' '배반의 여름' '한승원 삶과 문학' '조그만 체험기'
#  '박완서 소설전집2, In 모성, 그 생명과 평화' '자기정체성의 확인과 모성적 지평 in: 작가세계'
#  '자기정체성의 확인과 모성적 지평']
# ['경마장에서 생긴 일']
# ['글쓰기와 글치기']
# ['라디오 데이즈' '세계의 모든 해변처럼' '우주적인 안녕' '사이,들' '창작과비평'
#  '식민지 문학 연구의 역사주의적 전환과 전망']
# ['민중의 삶, 새마을운동의 새로운 발견과 역사성의 근원  \t김영미,   그들의 새마을운동']
# ['문학의 교육, 문학을 통한 교육' '1970년대 문학연구' '주체성의 복원과 성찰의 서사, in:   1960년대 문학연구'
#  '한국전쟁의 시공간성과 1960년대 소설의 새로움']
# ['이장호 민중영화의 여성 재현 - <바람 불어 좋은 날>, <바보선언>을 중심으로 -']
# ['집의 지형\uf000' '집의 지층\uf000']
# ['그대의 차가운 손']
# ['지옥의 소설 읽기 : 허구의 <환상소설>' '한 망명 예술가의 화두, 20세기 인류사의 화두 , 한기 , 합리주의의 문턱에서']
# ['마해송 동화 연구']
# ['채식주의자' '내 여자의 열매' '어둠의 사육제, In 여수의 사랑' '아버지는 지금, 책상 앞에 앉아 계신다'
#  "[대담] 한강 소설의 미학적 층위-'채식주의자'에서 '흰'까지"]
# ['남성지배체제에 경종 울려']
# ['책 이야기']
# ['고령화 사회의 노인의 정체성에 관한 연구']
# ['만성질환 노인의 부양체계로서의 가족의 역할: 21세기 변화 전망치 지원책 모색']
# ['나는 왜 ‘여성’이 되었는가-박완서 장편소설 『목마른 계절』(1978)론'
#  '1970년대 여성문학장의 형성과 ‘보통’ 여성의 작가적 시민권 주장 —박완서를 중심으로'
#  '자본주의를 비판하며 자본주의와 교섭하기' '노인성 치매 연구'
#  '‘전쟁 모성’이 생산한 여성 의식－박완서의 장편소설 『나목』(1970), 『그 산이 정말 거기 있었을까』(1995), 『그 남자네 집』(2004)을 중심으로－'
#  '박완서 작가 연구 – 대중·민중·여성문학장에서 ‘주부’의 발화 위치를 중심으로'
#  '1960년대 근대화와 ‘보통’ 여성의 문학 행위 －박완서의 『나목』 창작 및 등단 과정을 중심으로'
#  '박완서 작가 연구-대중·민중·여성문학장에서 ‘주부’의 발화 위치를 중심으로'
#  '비극적으로 아름다워야 한다는 조건 －1990년대 여성문학의 제도 문학 편입 맥락과 그 과정'
#  '박완서 작가 연구 : 대중 ‧ 민중 ‧ 여성문학장에서 ‘주부’의 발화 위치를 중심으로']
# ['공간의 정치경제학']
# ['구술사로 읽는 한국전쟁']
# ['한류에서 교류로']
# ['오늘의 영성신학']
# ['은유와 환유\uf000' '은유와 환유']
# ['노년학의 이해\uf000' '노년학의 이해']
# ['농지개혁사연구']
# ['한국문학번역원 10년사']
# ['한국문학과 민족주의' '페미니즘은 휴머니즘이다-90년대 문제작가를 진단한다']
# ['문학비평용어사전(하)' '문학비평용어사전(상)' '문학비평용어사전']
# ['2014 한류백서']
# ['한국 근현대예술사 구술채록연구 시리즈 108, 박완서' '문예연감']
# ['문예연감']
# ['한국민족문화대백과사전']
# ['離散家族을 찾습니다-TV 특별 생방송 138일의 기록' '離散家族을 찾습니다-KBS 특별 생방송 이산가족을 찾습니다 기록물 도록'
#  'KBS 연지 1981']
# ['새한불사전 Nouveau dictionnaire coreen-francais']
# ['한국 사회의 신분계급과 사회변동']
# ['참된 만남-한국의 엽편소설 50선']
# ['여성학 강의']
# ['여성']
# ['한국여성문학 연구의 현황과 전망' '페미니즘 지식문화의 동아시아적 유동과 변환']
# ['여원 연구']
# ['여원 연구 – 여성․교양․매체']
# ['거리에 선 페미니즘 - 여성 혐오를 멈추기 위한 8시간, 28800초의 기록']
# ['젠더와 사회' '여성의 몸' '여성의 몸 : 시각․쟁점․역사' '새 여성학 강의']
# ['여성해방문학의 논리']
# ['자료를 통해 본 한국 여성 삶의 변화']
# ['논쟁으로 본 한국 사회 100년']
# ['페미니즘, 어제와 오늘']
# ['《자유부인》(DVD), 2005']
# ['한국현대예술사대계 6 : 1990년대']
# ['상품집중분석–세탁기']
# ['한국전쟁전후 민간인학살 실태보고서']
# ['1970년대 전반기의 정치사회변동' '한국전쟁과 사회구조의 변화(한국현대사의 재인식7)']
# ['악이란 무엇인가']
# ['한국개화기문학총서-신소설?번안(역)소설1']
# ['‘각색’을 통한 문학과 영상의 통합 교육 방안' '장소감에 따른 기억의 재서술-박완서의 ≪그 남자네 집≫을 중심으로']
# ['시간의 서사화와 의사소통-<엄마를 부탁해>와 <도가니>의 분석' '한국 여성작가와 ‘환상’의 미적 욕망 연구']
# ['개별성-관계성과 자기위로능력관계에서자의식의 조절효과']
# ['습작기(1919~1920)의 심훈 신자료 소개와 관련하여' '‘불온문서’의 창출과 식민지 출판경찰'
#  '근대잡지와 근대문학 형성의 제도적 연관-1910년대 최남선과 竹內錄之助의 활동을 중심으로'
#  '염상섭 문장 전집 Ⅲ 1946-1962']
# ['베스트셀러 30년']
# ['예루살렘의 아이히만' '인간의 조건' '[단행본] 인간의 조건']
# ['멜라니클라인: 멜라니클라인의정신분석학']
# ['헤겔 철학사상의 이해']
# ['인간의 동기심리']
# ['고령사회의 이해 –노년과 사회']
# ['썩 물렀거라 자전거']
# ['한국전쟁과 수복지구' "한국전쟁 전후 '수복지구'의 체제 변동 과정 : 강원도 인제군을 중심으로"
#  "'수복지구' 주민의 정체성 형성과정-'인민'에서 '주민'으로 '주민'에서 '국민'으로"
#  '한국전쟁기 남한(유엔군)·북한의 점령통치에 대한 연구사 검토와 제언']
# ['아버지' '유수암, in: 한무숙 문학전집 4' '한국대표문학전집  8']
# ['황순원 소설의 문체번역 가능성 —「소나기」를 중심으로']
# ['개구리’ 상징에 대한 고찰']
# ['피로사회']
# ['양귀자 소설의 현실인식 연구 : 『원미동 사람들』, 『나는 소망한다 내게 금지된 것을』과 『모순』을 중심으로']
# ['계급 이론과 계층 이론']
# ['새로 쓰는 결혼 이야기 2']
# ['가면권력' '전시 북한의 반동분자 처리: 군중심판과 두문' '가면 권력 : 한국전쟁과 학살']
# ['박완서 단편소설의 자전적 인물 변화양상 고찰']
# ["한국 문학장에서 '정치적 올바름'은 어떻게 상상되고 있는가? : <82년생 김지영> 논쟁을 중심으로"]
# ['타인의 얼굴,In 모래 위의 집']
# ['소설과 일상성' '친일문학의 재인식' '내부망명자의 고독 - 안수길 후기소설에 나타난 ‘망명의식’의 문제를 중심으로'
#  '논쟁으로 읽는 한국사 2']
# ['한 소설가의 심리적 기원에 관한 고찰: 이청준의 데뷔작 퇴원 을 중심으로']
# ['소문의 역사' '소문의 역사-역사를 움직인 신과악마의 속삭임']
# ['소문의 역사']
# ['나체와 수치의 역사']
# ['이광수연구' '현대소설의 성 윤리-일부일처제와 성윤리를 중심으로' '동성애적 관점에서 본 무정' '미국에서의 한국 현대문학 교육'
#  '<무정>에 나타난 시간의식 연구' '이광수 연구' '현대소설사 기술방법의 반성과 새로운 모색, in 한국 전통비평론 탐구'
#  '현대소설의 성 윤리－일부일처제와 성윤리를 중심으로' '동성애적 관점에서 본 <무정>' '<무정>의 마르크스 비평적 연구'
#  '<무정>에 나타난 ‘친밀감의 거부’ 방어 기제' '구조주의적 관점에서 본 <무정>'
#  '페미니즘적 시각에서 본 『무정』  -가부장제 이데올로기에 희생된 젊은이들' '형식주의 비평적 관점에서 본 『무정』'
#  '해체주의 비평적 관점에서 본 ｢무정｣' '신역사주의 비평적 관점에서 본 <무정>' '황순원 장편소설 연구 죄의식을 중심으로']
# ['최인훈의 작가의식과 패로디 소설 고찰']
# ['피플 붓다' '소설, 노년을 말하다' '잠수거미' '희망사진관' '물에 잠긴 아버지' '한승원의 글쓰기 교실' '아리랑 별곡'
#  '그 바다,끓며 넘치며' '바다의 뿔' '갯비나리' '해일']
# ['소설,노년을 말하다']
# ['심훈연구-작가의식을 중심으로']
# ['1970년대 『창작과 비평』 민족문학론 연구']
# ['김주영 성장소설 연구 : 부권 부재 상황을 중심으로']
# ['개발 신화의 승인과 폭로, 도시 난민의 영화적 재현 -1980년대 초반 한국 영화를 중심으로-']
# ['한반도는 아프다-적대적 공생의 비극']
# ['소설학 사전' '소설학사전' '서사 이론과 그 쟁점들']
# ['교차성×페미니즘']
# ['한국현대 신문연재소설연구\uf000' '한국현대 신문연재소설연구']
# ['68년 전의 월미도 미군폭격, 아직도 피난중인 원주민들']
# ['인권변론 한 시대']
# ['한일 역사인식 논쟁의 메타히스토리']
# ['서사의 이론']
# ['한국 현대소설에 나타난 신화적 특성의 일 고찰 - 윤대녕 장편 <호랑이는 왜 바다로 갔나>를중심으로 -'
#  '심훈의 시와 소설을 통해 본 작가의식의 변모 과정' '박경리 『토지』의 문학사상 연구-『토지』와 동학사상의 관련 양상']
# ['교육 노년학']
# ['내포문에서의 화제화 제약과 정보구조']
# ['이인성 소설 연구']
# ['강남의 탄생']
# ['조선 비판적 사실주의 문학 연구']
# ['?한국사회 지배이데올로기의 형성과 재생산? ??한국인문사회과학의 현 단계와 전망??']
# ['세계문학으로서 한국문학:  번역과 번역공정의 문제에 대한 고찰']
# ['고등학교 국어 교과서에 수록된 현대소설의 특성과 교육방법에 관한 연구']
# ['지나간 미래']
# ['문학독서 교육, 어떻게 할 것인가']
# ['2000년대 이후 한국 문학의 러시아어 번역 출판 현황에 관한 연구']
# ['해방 공간에 있어서의 채만식의 현실 인식과 글쓰기, In 해방 공간의 문학운동과 문학의 현실인식'
#  '서울 현대의 삶과 박완서 소설 : ｢나목｣, ｢도시의 흉년｣, ｢휘청거리는 오후｣, ｢서울사람들｣을 중심으로']
# ['박완서의 두 겹의 글쓰기']
# ['유신－오직 한 사람을 위한 시대']
# ['뜻으로 본 한국사' '죽을 때까지 이 걸음으로']
# ['부엌의 문화사' '중산층의 정체성과 소비문화']
# ['오늘의 문제작 - 옛우물']
# ['한국전쟁과 여성-경계에 선 여성들']
# ['유인원 사이보그 그리고 여자']
# ['시적 영향에 대한 불안']
# ['역사의 요동']
# ['한국 개인용 컴퓨터 재현표상과 담론의 문화사 : 1980년대부터 2010년까지']
# ['수치의 윤리, 그 실천적 함의' '젠더 관점에서 본 아시아 여성의 재난 취약성' '여성주의적 ‘자율성’ 개념을 위한 시론'
#  '여성의 행위성과 가족 관념의 재구성' '관계적 자율성에 대한 철학적 연구 - 절차적 자율성과 실질적 자율성 논쟁을 중심으로 -']
# ['여성소설에 나타난 내면의식의 형상화 연구 ― 오정희의 옛 우물을 중심으로']
# ['민족 수난사의 환유와 신화적 사고의 표상 - 하근찬 소설을 중심으로 -']
# ['대학시절']
# ['6월 항쟁과 문학장의 민주화: 해금 전후(사)의 역사 인식과 항쟁 이후의 문학(론)']
# ['제노사이드와 기억의 정치']
# ['2000년대의 한국소설과 환상의 몫' '안수길의 신문연재 소설에 나타난 연애와 풍속 -『제2의 청춘』과 『부교』를 중심으로-']
# ['감수성과 상상력의 리얼리즘- 1970년대 초기 『문학과 지성』의 문학론과 ‘지성’의 함의']
# ['박경리 「가을에 온 여인」의 멜랑꼴리적 주체 연구']
# ['독서활동을 통한 문학치료 방법 연구']
# ['고령화 사회의 노인역할 프로그램에 관한 연구']
# ['1950년대 한국소설의 남성 젠더 수행성 연구'
#  '페미니즘 2.0 - 레베카 솔닛, 『남자들은 자꾸 나를 가르치려 든다』(창비, 2015) 윤보라 외, 『여성혐오가 어쨌다구?』(현실문화연구, 2015)'
#  '포스트 세계문학과 여성-이주-장편서사의 윤리학: 황석영의 『바리데기』를 중심으로'
#  '기억의 탈역사화와 사이의 정치학 - 최정희의 녹색의 문 연작을 중심으로－' '1980년대 여성해방운동과 번역의 역설'
#  '한국전쟁과 히스테리의 전유  —전쟁미망인의 섹슈얼리티와 전후 가족질서를 중심으로'
#  '1990년대 페미니스트 여성 대중의 등장과 잡지 『페미니스트저널 if』의 정치학' '광장의 페미니즘과 한국문학의 정치성'
#  '모니크 위티그의 스트레이트 마인드 : 이성애 제도에 대한 전복적 시선']
# ['동공에 박제된 연인']
# ['김수영 지우기']
# ['1950년대 전반 미국의 ‘생체정치’와 한국사회 헤게모니 구축 ―주한미군 민사기구의 활동과 성격―'
#  '영상과 아카이빙 그리고 새로운 역사쓰기']
# ['텍스트 분석과 텍스트 언어학의 전망, In 텍스트 분석의 실제']
# ['경험의 구원 가능성과 개념적 전개']
# ['서발턴 이론의 관점에서 본 이주민의 문학적 재현']
# ['박완서의 『미망』에 나타난 근대 재고의 한 형식' '박완서의 『미망』에 나타난 이데올로기 연구']
# ['1990년대 페미니즘의 대중화, 그 직전의 풍경' '출렁이는 시간〔들〕: 제4물결 페미니즘과 한국의 동시대 페미니즘']
# ['이순신의 문학적 형상화 연구']
# ['프랑스 혁명의 가족로망스']
# ['장르론']
# ['19세기 유럽의 역사적 상상력-메타 역사']
# ['돌봄 : 돌봄윤리']
# ['성의 계약']
# ['서사양식_단편소설의 기법']
# ['마지막 테우리']
# ['새 세계가 왓네']
# ['적치 6년의 북한문단']
# ['노인복지학 신론']
# ['가련한 연인의 초상']
# ['참된 만남-한국의 엽편소설 50선']
# ['문화와 권력']
# ['원본 한중록']
# ['픽션들']
# ['문화의 위치']
# ['박완서 문학앨범' '모든 것에 따뜻함이 숨어 있다' '우리 시대의 소설가 박완서를 찾아서' '어머니와 나'
#  '우리가 참 아끼던 사람 (소설가 박완서 대담집)']
# ['우리가 참 아끼던 사람']
# ['학문사회에 대한 기말 리포트, In 모색3']
# ['베르그손과 메를로-퐁티의 우리의 몸에 대한 이해 비교']
# ['미망']
# ['모녀관계와 여성 욕망 정체감: 크리스테바의 욕망이론']
# ['북한의 문예이론, In 북한의 문학과 문예이론']
# ['파국의 상상력: 포스트묵시록 문학과 재난문학']
# ['사회계층․계급론' '한국사회발전과 중산층의 역할' '한국의 중산층']
# ['신학적 구원과 시적구원']
# ['결혼이주여성이 인지한 문화적응스트레스와 부부적응에 관한 연구 : 사회적 지지와 부부의사소통의 매개효과를 중심으로']
# ['니체의 음악적 사유와 현대성 - 바그너, 한슬릭, 쇤베르크와의 관계를 중심으로']
# ['우리들의 두 여인' '우리집 여인들']
# ['황진이' '황진이 1-2']
# ['취향의 정치학-피에르 부르디외의 구별짓기 읽기와 쓰기' '취향의 정치학'
#  '피에르 부르디외와 한국사회 : 이론과 현실의 비교정치학']
# ['서발턴에 대한 진실한 기록, 1970년대 르포' '1920년대 후반 장편소설(掌篇小設)의 출현과 새로운 형식 실험']
# ['대한민국 1세대 아파트를 통해 본 한국인의 주거문화 변화에 관한 연구']
# ['해방 후 사회경제의 변동과 일상생활']
# ['한국 생태문학 연구총서1' '개발독재와 박정희시대' '생명의 강을 위하여 : 생태사회학자 홍성태 교수의 4대강 지키기 제안']
# ['국가폭력 연구의 최근 경향과 새로운 연구 방향 모색']
# ['노년학개론' '노년학 개론' '고학력 여성 퇴장 많다']
# ['전쟁과 국가폭력']
# ['이순신 정론ⅴ-이순신 사망설의 진위 논쟁']
# ['공간의시학']
# ['박경리 「토지」 연구 :  존재론적 생극론을 중심으로']
# ['목회자 아내의 정체성 확립을 위한 통합적 개념으로서의 영적 성숙 연구 : 캐롤 길리건(Carol Gilligan)의 돌봄과 헨리 나우웬(Henri Nouwen)의 영혼돌봄 개념 중심으로']
# ['부정의 정신과 생명의지, 아름다운 결핍의 신화']
# ['디아스포라, 민족과 자아 그리고 융합의 글쓰기 -재일동포 한국어 수필을 중심으로-'
#  '나마스테에 나타난 외국인 노동자의 재현 양상']
# ['늙어도 젊은 것과 젊어도 늙은 것']
# ['전후 일본의 족(族) 문화와 ‘천황’의 부재(不在) ― 미시마 유키오(三島由紀夫) 「달(月)」에 나타난 젊은 세대의 문화 ―']
# ['30년대초의 농촌과 심훈 문학-<상록수>를 중심으로']
# ['서사의 이미지화를 통한 상상력 교육 연구: 소설 각색 만화를 중심으로' '소설의 수사적 읽기 교육 연구를 위한 시론(試論)'
#  '‘갈등’의 교육적 구현 양상 연구: 2015 개정 국어과 교육과정에 따른 고등학교 『국어』, 『문학』 교과서를 중심으로'
#  '문학교육 제재로서 박완서 소설의 수록 양상 고찰']
# ['문학과 지성사 30년' '원미동 사람들' '한 여자 작가의 자기사랑, 역사적 삶과 비평'
#  '한 여자 작가의 자기 사랑, In 박완서론' '한 여자 작가의 자기 사랑' '역사적 삶과 비평' '님' '노을'
#  '김지하 전집4: 이것 그리고 저것']
# ['명동 역사 속 문화적 재구성']
# ['<주체 없는 과정>인가, <과정으로서의 주체>인가―정신분석학과 알튀세르―' '라캉의 정신병 이론과 그 사회철학적, 윤리적 의미'
#  '도시, 성, 사랑' '르페브르의 공간 및 도시공간 이론에 대한 정신분석적 고찰: 『공간의 생산』을 중심으로'
#  '고통 받는 주체, 그 무의식을 바라본다 in 지식의 최전선' '오이디푸스 콤플렉스, 남자의 성, 여자의 성']
# ['코로나 시대의 돌봄을 바라보는 다양한 시선들 - ‘돌봄 위기’에 대한 <조선>,<중앙>,<한겨레>,<경향>의 기사 내용분석을 중심으로.']
# ['1970년대 [샘터]지와 ‘교양’담론 연구']
# ['페미니즘 시각에서 본 박완서 소설 연구 : 80년대 소설을 중심으로']
# ['한국사회의 압축적 개인화와 젠더범주의 민주주의적 함의 - 1990년대를 중심으로']
# ['민족주의적 통치성과 ‘국민’ 만들기: 해방 이후 남한에서 반공과 경제개발 주체로서 ‘국민’의 탄생' '현대정치철학의 모험']
# ['젠더의 역사적 구성: 성별관계와 여성경제사']
# ['개성상인']
# ['한국주거의 사회사']
# ['억지로 잠자는 노인들 ... 요양병원에 무슨 일이']
# ['박완서 문학에 투영된 6.25 전쟁' '박완서 문학에 투영된 6·25전쟁' '김원일의 가족사 소설']
# ['[단행본] 깃발']
# ['앓던 모든 것']
# ['한국문학선집:북한편']
# ['이청준 소설에 나타난 예술적 주체의 죽음과 소설론의 상관성 연구']
# ['박완서 「옥상의 민들레꽃」의 문학 교육적 가치 연구']
# ['모성과 보편적 여성성 – 공선옥의 <내 생의 알리바이' '창작과 비평 57' '민족문제의 개인주의적 굴절'
#  '민족문제의 개인주의적 굴절-朴婉緖 長篇小說 『그해 겨울은 따뜻했네』' '빨치산 기록물과 그 소설화']
# ['한국소설의 말년에 관한 사유' '한국소설의 말년에 대한 사유' '남북한 역사소설의 거리'
#  '90년대 소설의 환상성,그 상상력의 모험']
# ['우리시대의 여성작가' '문체로 읽는 소설' '정체성 확인의 글쓰기-박완서의 ｢엄마의 말뚝1｣의 경우' '이야기는 힘이 세다'
#  '우리 시대의 여성작가' '물화의 공포와 유혹' '정체성 확인의 글쓰기'
#  '뒤틀린 성, 부서진 육체-오정희 소설의 한 풍경 in: 욕망의 그늘' '환상 속으로 탈주하라 in : 환각'
#  '여성의 글쓰기와 꿈꾸기, 그 여성성의 지평' '어긋나는 말, 혹은 감추어진 말(우리 시대의 여성 작가)'
#  '불을 안고 강 건너기 불의 강의 문체론적 분석(오정희 깊이 읽기)' '뒤틀린 성, 부서진 육체'
#  '행주치마를 두른 글쓰기와 글읽기?']
# ['한국 근현대문학에 나타난 가족담론의 전개와 그 의미: 현대소설']
# ['죽을 권리와 죽일 권능 ― 용어의 정리를 제안하며 ―']
# ['매개 접촉 활용 사회과 수업이 청소년의 연령차별주의에 미치는 영향']
# ['박정희 시대의 국가와 ‘민중’' '1970년대 중산층의 소유 욕망과 불안 : 박완서의 1970년대 저작을 중심으로'
#  '해방 공간 한민당의 ‘냉전 자유주의’와 사유재산 담론- 토지개혁 구상을 중심으로' '박정희와 근대적 출세 욕망'
#  '유신체제의 대중인식과 동원 담론' '박정희 체제의 지배담론 : 근대화 담론을 중심으로' '대중독재-강제와 동의 사이에서'
#  '[1970 박정희부터 선데이서울까지](14) 고교 평준화' '1970년대 ‘복부인’의 경제적 표상과 문화적 재현']
# ['오래된 정원-상/하' '무기의 그늘(하)' '무기의 그늘 상 ․하' '장사의 꿈'
#  'The Road to Sampo, In Modern Korean Short Stories' '객지'
#  'Le Vieux Jardin.Cadeilhan' '황석영 중단편 전집 1권' '황석영 중단편 전집 2' '客地' '잡초'
#  '삼포 가는 길' '무기의 그늘' '어둠의 자식들' '객지에서 고향으로' '탑을 쌓는 일과 소설을 쓰는 일' '장길산'
#  '무기의 그늘(상?하)' '황석영의 한국명단편 101, 4권' '황석영의 명단편 101' '해질 무렵']
# ['생태여성주의와 문학']
# ['최정희 문학 연구']
# ['이문구 동시 연구']
# ['베르그손－지속과 생명의 형이상학']
# ['별과 같이 살다 / 카인의 후예 Byeol-gwa gachi salda' 'Le vieux Hwang' '목넘이마을의 개/곡예사'
#  '탈/기타' '시선집' '독짓는 늙은이' '읽자 읽자 우리 소설' '曲藝師' '황순원 전집2']
# ['다양한 삶속의 응고된 혼, 또는 열림']
# ['박태원 소설의 여성인물과 근대성' '박범신 소설 ≪은교≫의 영화화 연구'
#  '덫이 된 가정에서의 존재론적 탐색 : 오정희의 초기 소설']
# ['입양인 디아스포라와 친생모의 서사:『누군가의 딸』을 중심으로']
# ['노년서사의 문학교육적 의미 연구 : 박완서 소설을 중심으로']
# ['지역사회 거주 노인의 성생활과 삶의 만족도 간 관계']
# ['질병과 이야기－문학과 의학이 만나는 지점들－']
# ['여성 사회권의 담론적 구성과 아내.어머니.노동자 지위']
# ['가치로서의 돌봄' '미술의 심상적 표현을 위한 색채 연구'
#  "'결을 거슬러 역사를 솔질'하는 문학: 『밤의 눈』과 『소년이 온다』"
#  '지나간 미래와 오지 않은 과거 — 코젤렉과 개념사 연구 방법론 —']
# ['파씨의 입문' '파묘']
# ['상시화된 예외상태와 민주주의   박정희 지배담론과 주체주의 변혁담론을 중심으로']
# ['모더니즘의 망령을 찾아서, 모더니티란 무엇인가' '비루한 것의 카니발' '『타인에게 말 걸기』 해설' '바루한 것의 카니발'
#  '탈승화의 리얼리즘, In 문학동네' '탈승화의 리얼리즘' '여성소설과 전설의 우물(비루한 것의 카니발)' '김주영 깊이 읽기'
#  '개인 주체로의 방법적 귀환' '90년대 문학을 어떻게 볼 것인가' '겨울 우화'
#  '『늪을 건너는 법』 혹은 포스트모던 로만스–소설의 탄생—한국문학의 1990년대를 보는 한 관점'
#  '『늪을 건너는 법』 혹은 포스트모던 로만스-소설의 탄생- 한국문학의 1990년대를 보는 한 관점' '여성소설과 전설의 우물'
#  '90년대 문학어떻게 볼 것인가' '한일 역사인식 논쟁의 메타히스토리: ‘한일, 연대21’의 시도']
# ['조선책략']
# ['조선책략']
# ['채만식 문학에 나타난 ‘가족’과 ‘자본’:「심봉사」와 「흥부傳」 을 중심으로']
# ['지역패권의 나라']
# ['모험하는 언어와 서정시' '염소를 모는 여자' '한ㆍ생명ㆍ대자대비 - 『토지』 비평집 2']
# ['독학의 진격자들-스스로 배움을 찾아 나선 사람들의 이야기']
# ['비판적으로 읽는 일본 군인 회고록 속 ‘위안부’']
# ['4·19/5·16시기의 반공체제 재편과 그 논리 ― 반공법의 등장과 그 담지자들']
# ['번역과 주체']
# ['2020 하류노인이 온다']
# ['전향의 사상사적 연구']
# ['텍스트성·철학·예술: 해석학과 해체주의 사이']
# ['沈熏硏究 : 生涯와 作品']
# ['표상공간의 근대']
# ['한국여성운동사 연구 : 미군정기 여성운동을 중심으로']
# ['박완서 「엄마의 말뚝」에 나타난 서사 전략 연구']
# ["해방직후의 소설 연구 : `길'의 상징성을 중심으로"]
# ["`어린이'誌에 나타난 兒童文學 樣相 연구"]
# ['殉國革命家列傳' '古今東西 文學鑑賞讀本－特히文學志望者를위하야－' '改訂版 文學鑑賞讀本－特히文學志望者를위하야－' '文學과鑑賞']

# %%
# Create a dictionary to hold the best match for each title based on the author
title_mapping = {}

# Group data by author
for author, group in data.groupby('author'):
    titles = group['title'].unique()  # unique titles for this author

    for title in titles:
        # Generate a list of other titles by the same author to compare against
        other_titles = [t for t in titles if t != title]

        if other_titles:
            # Find the most similar title to the current one (excluding the same title)
            best_match, score, _ = process.extractOne(title, other_titles, scorer=fuzz.token_sort_ratio)
            
            # Apply a threshold to consider as a match
            if score > 85:  # threshold of 80 out of 100
                title_mapping[(author, title)] = best_match
            else:
                title_mapping[(author, title)] = title  # no similar title found, map to itself
        else:
            # If no other titles are available, map the title to itself
            title_mapping[(author, title)] = title
            
# Apply the mapping to the 'title' column
data['unified_title'] = data.apply(lambda row: title_mapping[(row['author'], row['title'])], axis=1)

# %%
# 'unified_title' 열에서 각 제목의 빈도 계산
title_counts = data['unified_title'].value_counts()

# 빈도가 2 이상인 제목만 필터링
repeated_titles = title_counts[title_counts > 1].index.tolist()

# 'title' 열이 repeated_titles 리스트에 해당하는 경우, 'unified_title' 열을 'title' 열의 값으로 설정
data['unified_title'] = data.apply(lambda row: row['title'] if row['title'] in repeated_titles else row['unified_title'], axis=1)

# %%
# Save the results to a new CSV file
data.to_csv('p2_solved_thres85_token_sort_ratio.csv', encoding='utf-8-sig', index=False)

# %%
data['unified_title'].value_counts().head(50)
# Out:
# unified_title
# 한국 현대 노년소설 연구                                                                                                34
# 그 많던 싱아는 누가 다 먹었을까                                                                                           31
# 박완서 문학 길찾기                                                                                                   29
# 소설, 노년을 말하다                                                                                                  24
# 그 산이 정말 거기 있었을까                                                                                              22
# 나목                                                                                                           21
# 부끄러움을 가르칩니다                                                                                                  20
# 엄마의 말뚝 2                                                                                                     20
# 한국문학에 나타난 노인의식                                                                                               18
# 그 남자네 집                                                                                                      17
# 박완서 소설과 ‘비평’: 공감과 해석의 논리                                                                                     17
# 장소와 장소상실                                                                                                     17
# 목마른 계절                                                                                                      16
# 반공주의와 자전소설의 형식 - 박완서를 중심으로                                                                                   16
# 생존과 수치 - 1970년대 박완서 소설과 생존주의의 이면 (1)                                                                         16
# 박완서 소설에 나타난 중산층 정체성 형상화 연구                                                                                   16
# 공간과 장소                                                                                                       16
# 박완서 문학 길 찾기                                                                                                  15
# 현대소설에 나타난 ‘치매’의 의미                                                                                           15
# 노년                                                                                                           15
# 박완서 노년소설의 젠더시학                                                                                               15
# 빛나는 성좌들 - 1980년대, 여성해방문학의 탄생                                                                                 14
# 박완서 소설의 대중성 연구-1980년대 여성문제 소설 다시 읽기                                                                          14
# 세계화와 탈냉전에 대응하는 소설의 형식 : 기억으로 발언하기 - 1990년대 박완서 자전소설의 의미 연구                                                   14
# 배반의 여름                                                                                                       14
# 한국 현대 노년소설 연구사                                                                                               14
# 한국전쟁의 기억과 장소 연구 -박완서 소설을 중심으로-                                                                               13
# 젠더 트러블                                                                                                       13
# 모녀 서사를 통해 본 ‘치매’의 상징성 연구                                                                                     13
# 박완서 소설의 젠더 의식 연구 : 수행성을 중심으로                                                                                 13
# 박완서 소설의 전쟁 진술 방식 차이점 연구- ｢엄마의 말뚝｣, 목마른 계절 , 나목 , 그 많던 싱아는 누가 다 먹었을까 ,  그 산이 정말 거기 있었을까 의 오빠 관련 서술을 중심으로 -    13
# 소설에서의 치매 서사의 수용                                                                                              13
# 박완서 노년소설에 나타나는 질병의 의미                                                                                        13
# 자서전의 규약                                                                                                      13
# 박완서 소설에 나타난 애도와 죄의식에 관한 연구                                                                                   12
# 기억의 공간                                                                                                       12
# 박완서 소설에 나타난 ‘먹는 인간’의 의미: 초기 장편소설을 중심으로                                                                       12
# 휘청거리는 오후                                                                                                     12
# ‘여성’의 사회적 해석과 1976년의 박완서 소설-《휘청거리는 오후》의 대중성을 중심으로-                                                           12
# 박완서 노년소설의 시학과 문학적 함의(II)                                                                                     12
# 박완서 노년 소설의 담론 특성과 문학적 함의                                                                                     12
# 전쟁과 사회                                                                                                       12
# 가부장제와 자본주의                                                                                                   11
# 문체로 읽는 소설                                                                                                    11
# 그 여자네 집                                                                                                      11
# 박완서의 자전적 근대 체험과 토포필리아-『그 많던 싱아는 누가 다 먹었을까』를 중심으로                                                             11
# 서 있는 여자                                                                                                      11
# 사회비평 이상의 것                                                                                                   11
# 박완서 소설의 환 양상 연구                                                                                              11
# 증언의 양식, 생존ㆍ성장의 서사-박완서의 전쟁 재현 소설『그 산이 정말 거기 있었을까』를 중심으로                                                       11
# Name: count, dtype: int64

# %%
data[data['unified_title'] == '1990년대 페미니즘의 대중화, 그 직전의 풍경']
data[data['unified_title'] == '1990년대 페미니즘의 대중화, 그 직전의 풍경'].to_csv('unified_a_book.csv', encoding='utf-8-sig', index=False)
